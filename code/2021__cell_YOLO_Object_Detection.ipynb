# %% [markdown]
# # 물체 탐지(Object Detection)
# ### 2021 07 22 수정

# %% [markdown]
# ## Darknet 준비

# %%
'''
# !pip3 uninstall -y keras
# !pip3 uninstall keras-nightly
# !pip3 uninstall -y tensorflow



# !pip3 install keras==2.1.6
# !pip3 install tensorflow==1.13.1
# !pip3 install h5py==2.10.0

'''
# Out:
# '\n!pip3 uninstall -y keras\n!pip3 uninstall keras-nightly\n!pip3 uninstall -y tensorflow\n\n\n\n!pip3 install keras==2.1.6\n!pip3 install tensorflow==1.13.1\n!pip3 install h5py==2.10.0\n\n'

# %%
# !pip uninstall -y tensorflow-gpu==1.13.1
# Out:
# Found existing installation: tensorflow-gpu 1.13.1
# Uninstalling tensorflow-gpu-1.13.1:
#   Successfully uninstalled tensorflow-gpu-1.13.1

# %%
# !pip3 install tensorflow-gpu==1.13.1
# Out:
# Collecting tensorflow-gpu==1.13.1
#   Using cached tensorflow_gpu-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (345.0 MB)
# Requirement already satisfied: protobuf>=3.6.1 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (3.17.3)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: wheel>=0.26 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (0.36.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.1.2)
# Requirement already satisfied: absl-py>=0.1.6 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (0.13.0)
# Requirement already satisfied: six>=1.10.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.16.0)
# Requirement already satisfied: astor>=0.6.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: grpcio>=1.8.6 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.38.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.0.8)
# Requirement already satisfied: gast>=0.2.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (0.5.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-gpu==1.13.1) (1.21.0)
# Requirement already satisfied: h5py in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (2.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.3.4)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (4.6.1)
# Requirement already satisfied: mock>=2.0.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.5.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.13.1

# %%
import tensorflow as tf
#print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59   from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# ~/anaconda3/envs/cell/lib/python3.7/imp.py in load_module(name, file, filename, details)
#     241         else:
# --> 242             return load_dynamic(name, filename, file)
#     243     elif type_ == PKG_DIRECTORY:
#
# ~/anaconda3/envs/cell/lib/python3.7/imp.py in load_dynamic(name, path, file)
#     341             name=name, loader=loader, origin=path)
# --> 342         return _load(spec)
#     343
#
# ImportError: libcublas.so.10.0: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-ce35dd35905d> in <module>
# ----> 1 import tensorflow as tf
#       2 #print(tf.__version__)
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 from tensorflow._api.v1 import app
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      47 import numpy as np
#      48
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      50
#      51 # Protocol buffers
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py in <module>
#      72 for some common reasons and solutions.  Include the entire stack trace
#      73 above this error message when asking for help.""" % traceback.format_exc()
# ---> 74   raise ImportError(msg)
#      75
#      76 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/imp.py", line 342, in load_dynamic
#     return _load(spec)
# ImportError: libcublas.so.10.0: cannot open shared object file: No such file or directory
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
import keras
print(keras.__version__)

# %%
# 프로젝트 다운로드
# %cd /home/ubuntu/cell
# Out:
# /home/ubuntu/cell

# %%
# !rm -rf darknet
# !git clone https://github.com/pjreddie/darknet

# %%
# 빌드
# %cd /content/darknet
# !make

# 빌드된 실행파일 확인
# !ls -al darknet

# 빌드 확인
# !./darknet
# Out:
# [Errno 2] No such file or directory: '/content/darknet'
# /home/ubuntu/cell
# make: *** 타겟이 지정되지 않았고 메이크파일이 없습니다.  멈춤.
# 합계 116
# drwxrwxr-x 10 ubuntu ubuntu  4096  7월 15 11:51 .
# drwxrwxr-x  5 ubuntu ubuntu  4096  7월 15 11:51 ..
# drwxrwxr-x  8 ubuntu ubuntu  4096  7월 15 11:51 .git
# -rw-rw-r--  1 ubuntu ubuntu   200  7월 15 11:51 .gitignore
# -rw-rw-r--  1 ubuntu ubuntu   515  7월 15 11:51 LICENSE
# -rw-rw-r--  1 ubuntu ubuntu   474  7월 15 11:51 LICENSE.fuck
# -rw-rw-r--  1 ubuntu ubuntu  6652  7월 15 11:51 LICENSE.gen
# -rw-rw-r--  1 ubuntu ubuntu 35141  7월 15 11:51 LICENSE.gpl
# -rw-rw-r--  1 ubuntu ubuntu   360  7월 15 11:51 LICENSE.meta
# -rw-rw-r--  1 ubuntu ubuntu  1071  7월 15 11:51 LICENSE.mit
# -rw-rw-r--  1 ubuntu ubuntu   461  7월 15 11:51 LICENSE.v1
# -rw-rw-r--  1 ubuntu ubuntu  3040  7월 15 11:51 Makefile
# -rw-rw-r--  1 ubuntu ubuntu  2535  7월 15 11:51 README.md
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 cfg
# drwxrwxr-x  3 ubuntu ubuntu  4096  7월 15 11:51 data
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 examples
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 include
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 python
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 scripts
# drwxrwxr-x  2 ubuntu ubuntu  4096  7월 15 11:51 src
# /bin/bash: ./darknet: 디렉터리입니다

# %% [markdown]
# ## 학습된 모델 파일 다운로드

# %%
# %cd /home/ubuntu/cell/darknet
# Out:
# /home/ubuntu/cell/darknet

# %%
# !wget wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-07-15 13:01:08--  http://wget/
# Resolving wget (wget)... 접속 실패: 이름 혹은 서비스를 알 수 없습니다.
# wget: unable to resolve host address ‘wget’
# --2021-07-15 13:01:08--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# 접속 pjreddie.com (pjreddie.com)|128.208.4.108|:443... 접속됨.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   150KB/s    in 48m 28s
#
# 2021-07-15 13:49:37 (83.3 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# FINISHED --2021-07-15 13:49:37--
# Total wall clock time: 48m 29s
# Downloaded: 1 files, 237M in 48m 28s (83.3 KB/s)

# %% [markdown]
# ## Keras 변환 코드 다운로드

# %%
# 다운로드
# %cd /content
# !rm -rf keras-yolo3

# !git clone https://github.com/qqwweee/keras-yolo3
  
# 다운로드된 디렉토리로 이동
# %cd keras-yolo3

# 내용 확인
# !pwd
# !ls -al
# Out:
# [Errno 2] No such file or directory: '/content'
# /home/ubuntu/cell
# 'keras-yolo3'에 복제합니다...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# 오브젝트를 받는 중: 100% (144/144), 151.08 KiB | 8.39 MiB/s, 완료.
# 델타를 알아내는 중: 100% (65/65), 완료.
# /home/ubuntu/cell/keras-yolo3
# /home/ubuntu/cell/keras-yolo3
# 합계 124
# drwxrwxr-x 6 ubuntu ubuntu  4096  7월 15 12:11 .
# drwxrwxr-x 6 ubuntu ubuntu  4096  7월 15 12:11 ..
# drwxrwxr-x 8 ubuntu ubuntu  4096  7월 15 12:11 .git
# -rw-rw-r-- 1 ubuntu ubuntu  1201  7월 15 12:11 .gitignore
# -rw-rw-r-- 1 ubuntu ubuntu  1064  7월 15 12:11 LICENSE
# -rw-rw-r-- 1 ubuntu ubuntu  4077  7월 15 12:11 README.md
# -rw-rw-r-- 1 ubuntu ubuntu  1323  7월 15 12:11 coco_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu 10093  7월 15 12:11 convert.py
# -rw-rw-r-- 1 ubuntu ubuntu  5707  7월 15 12:11 darknet53.cfg
# drwxrwxr-x 2 ubuntu ubuntu  4096  7월 15 12:11 font
# -rw-rw-r-- 1 ubuntu ubuntu  3482  7월 15 12:11 kmeans.py
# drwxrwxr-x 2 ubuntu ubuntu  4096  7월 15 12:11 model_data
# -rw-rw-r-- 1 ubuntu ubuntu  8332  7월 15 12:11 train.py
# -rw-rw-r-- 1 ubuntu ubuntu 10686  7월 15 12:11 train_bottleneck.py
# -rw-rw-r-- 1 ubuntu ubuntu  1416  7월 15 12:11 voc_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu  8540  7월 15 12:11 yolo.py
# drwxrwxr-x 2 ubuntu ubuntu  4096  7월 15 12:11 yolo3
# -rw-rw-r-- 1 ubuntu ubuntu  2304  7월 15 12:11 yolo_video.py
# -rw-rw-r-- 1 ubuntu ubuntu  1915  7월 15 12:11 yolov3-tiny.cfg
# -rw-rw-r-- 1 ubuntu ubuntu  8342  7월 15 12:11 yolov3.cfg

# %% [markdown]
# ## YOLO3 모델 파일 카피

# %%
# %cd /home/ubuntu/cell/keras-yolo3

# !cp /home/ubuntu/cell/darknet/yolov3.weights ./

# !ls -al yolov3.weights
# Out:
# /home/ubuntu/cell/keras-yolo3
# -rw-rw-r-- 1 ubuntu ubuntu 248007048  7월 15 13:55 yolov3.weights

# %% [markdown]
# ## 모델 파일 변환
#
# YOLO3 자체는 C/C++로 구현된 DarkNet 프레임웤으로 구현되어 있다.
#
# 공개된 모델은 DarkNet의 포멧이다. 이를 Keras에서 사용할 수 있는 h5 포멧으로 변환한다.
#
#
# - convert.py : 변환 실행 파일
#
# - yolov3.cfg : Darknet에서 사용하는 모델 구조 정의 파일
#
# - yolov3.weight : Darknet으로 학습된 모델 파일
#
#
# 실행 결과로 다음의 h5 파일로 변환된다.
#
# - model/yolov3.h5 : 변환된 모델 파일

# %%
# !head -40 yolov3.cfg
# Out:
# [net]
# # Testing
# batch=1
# subdivisions=1
# # Training
# # batch=64
# # subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1

# %%
'''
#tiny  추가 (송미경 수정)
# 실행하기전 기존것이 있다면 삭제

# !rm -rf yolov3-tiny.h5

# 실행 
# %run convert.py yolov3-tiny.cfg yolov3.weights yolov3-tiny.h5
'''
# Out:
# ERROR:root:File `'convert.py'` not found.

# %%
# 실행하기전 기존것이 있다면 삭제
# !rm -rf yolov3.h5

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
# 실행 
# %run convert.py yolov3.cfg yolov3.weights yolov3.h5
# Out:
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 255)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_1/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_40/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 255)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_2/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_32/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 255)
# Parsing section yolo_2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 3 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 3 128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, None, None, 3 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 6 18432       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 6 256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 6 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 3 2048        leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 3 128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 3 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 6 18432       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 6 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 6 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 6 0           leaky_re_lu_50[0][0]
#                                                                  leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, None, None, 6 0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 73728       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 1 512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 6 8192        leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 6 256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, None, None, 6 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 73728       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 1 512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           leaky_re_lu_53[0][0]
#                                                                  leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 6 8192        add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 6 256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, None, None, 6 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 73728       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 1 512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           add_23[0][0]
#                                                                  leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 2 1024        conv2d_59[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 1 512         conv2d_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 2 1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 2 0           leaky_re_lu_58[0][0]
#                                                                  leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 1 32768       add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 1 512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 2 0           add_25[0][0]
#                                                                  leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 1 32768       add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 1 512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 2 0           add_26[0][0]
#                                                                  leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 1 32768       add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 1 512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 2 1024        conv2d_67[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 2 0           add_27[0][0]
#                                                                  leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 32768       add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 2 1024        conv2d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 2 0           add_28[0][0]
#                                                                  leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 1 32768       add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 512         conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 2 1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, None, 2 0           add_29[0][0]
#                                                                  leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 1 32768       add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 1 512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 1024        conv2d_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, None, 2 0           add_30[0][0]
#                                                                  leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 1 32768       add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, None, None, 1 512         conv2d_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 2 1024        conv2d_75[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, None, 2 0           add_31[0][0]
#                                                                  leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, None, None, 2 0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 5 2048        conv2d_76[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 2 1024        conv2d_77[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 5 2048        conv2d_78[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, None, None, 5 0           leaky_re_lu_75[0][0]
#                                                                  leaky_re_lu_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 2 131072      add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 2 1024        conv2d_79[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 5 2048        conv2d_80[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, None, None, 5 0           add_33[0][0]
#                                                                  leaky_re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 2 131072      add_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 2 1024        conv2d_81[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 5 2048        conv2d_82[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, None, None, 5 0           add_34[0][0]
#                                                                  leaky_re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 2 131072      add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 2 1024        conv2d_83[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 5 2048        conv2d_84[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, None, None, 5 0           add_35[0][0]
#                                                                  leaky_re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 2 131072      add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 2 1024        conv2d_85[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 5 2048        conv2d_86[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, None, None, 5 0           add_36[0][0]
#                                                                  leaky_re_lu_85[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 2 131072      add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 2 1024        conv2d_87[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 5 2048        conv2d_88[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, None, None, 5 0           add_37[0][0]
#                                                                  leaky_re_lu_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 2 131072      add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 2 1024        conv2d_89[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 5 2048        conv2d_90[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, None, None, 5 0           add_38[0][0]
#                                                                  leaky_re_lu_89[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 2 131072      add_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 2 1024        conv2d_91[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 5 2048        conv2d_92[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, None, 5 0           add_39[0][0]
#                                                                  leaky_re_lu_91[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, None, None, 5 0           add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 1 4096        conv2d_93[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 5 2048        conv2d_94[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_93 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, None, None, 1 4096        conv2d_95[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_94 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, None, 1 0           leaky_re_lu_92[0][0]
#                                                                  leaky_re_lu_94[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, None, None, 5 524288      add_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, None, None, 5 2048        conv2d_96[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_95 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, None, None, 1 4096        conv2d_97[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_96 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, None, 1 0           add_41[0][0]
#                                                                  leaky_re_lu_96[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, None, None, 5 524288      add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, None, None, 5 2048        conv2d_98[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_97 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, None, None, 1 4096        conv2d_99[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_98 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, None, None, 1 0           add_42[0][0]
#                                                                  leaky_re_lu_98[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, None, None, 5 524288      add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, None, None, 5 2048        conv2d_100[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_99 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, None, None, 1 4718592     leaky_re_lu_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, None, None, 1 4096        conv2d_101[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_100 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, None, 1 0           add_43[0][0]
#                                                                  leaky_re_lu_100[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, None, None, 5 524288      add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, None, None, 5 2048        conv2d_102[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_101 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, None, None, 1 4718592     leaky_re_lu_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, None, None, 1 4096        conv2d_103[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_102 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, None, None, 5 524288      leaky_re_lu_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, None, None, 5 2048        conv2d_104[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_103 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, None, None, 1 4718592     leaky_re_lu_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, None, None, 1 4096        conv2d_105[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_104 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, None, None, 5 524288      leaky_re_lu_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, None, None, 5 2048        conv2d_106[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_105 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, None, None, 2 131072      leaky_re_lu_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, None, None, 2 1024        conv2d_109[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_107 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 2 0           leaky_re_lu_107[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           up_sampling2d_1[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, None, None, 2 196608      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, None, None, 2 1024        conv2d_110[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_108 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, None, None, 5 1179648     leaky_re_lu_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, None, None, 5 2048        conv2d_111[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_109 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, None, None, 2 131072      leaky_re_lu_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, None, None, 2 1024        conv2d_112[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, None, None, 5 1179648     leaky_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, None, None, 5 2048        conv2d_113[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, None, None, 2 131072      leaky_re_lu_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, None, None, 2 1024        conv2d_114[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, None, None, 1 32768       leaky_re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, None, None, 1 512         conv2d_117[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 1 0           leaky_re_lu_114[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           up_sampling2d_2[0][0]
#                                                                  add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, None, None, 1 49152       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, None, None, 1 512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, None, None, 2 294912      leaky_re_lu_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, None, None, 2 1024        conv2d_119[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_116 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, None, None, 1 32768       leaky_re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, None, None, 1 512         conv2d_120[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_117 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, None, None, 2 294912      leaky_re_lu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, None, None, 2 1024        conv2d_121[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_118 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, None, None, 1 32768       leaky_re_lu_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, None, None, 1 512         conv2d_122[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_119 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, None, None, 1 4718592     leaky_re_lu_105[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, None, None, 5 1179648     leaky_re_lu_112[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, None, None, 2 294912      leaky_re_lu_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, None, None, 1 4096        conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, None, None, 5 2048        conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, None, None, 2 1024        conv2d_123[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_106 (LeakyReLU)     (None, None, None, 1 0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)     (None, None, None, 5 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_120 (LeakyReLU)     (None, None, None, 2 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, None, None, 2 261375      leaky_re_lu_106[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, None, None, 2 130815      leaky_re_lu_113[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, None, None, 2 65535       leaky_re_lu_120[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Saved Keras model to yolov3.h5
# Read 62001757 of 62001757.0 from Darknet weights.

# %% [markdown]
# ## 물체 탐지 실행
#
# 다음의 파일이 필요하다.
# - yolov3.h5 : 모델 파일
# - model_data/coco_classes.txt : 클래스 이름

# %% [markdown]
# # 커스텀 데이터 적용

# %% [markdown]
# ## 커스텀 데이터 업로드

# %%
'''
#파일 수정해서 올릴때 필요한 코드

# %cd /content/keras-yolo3/resize_data
#! rm *

# %cd /content/keras-yolo3

#! rm resize_data.zip
#! rm -r resize_data/
'''
# Out:
# [Errno 2] No such file or directory: '/content/keras-yolo3/resize_data'
# /content/keras-yolo3
# rm: cannot remove 'font': Is a directory
# rm: cannot remove 'model_data': Is a directory
# rm: cannot remove 'yolo3': Is a directory
# /content/keras-yolo3
# rm: cannot remove 'resize_data.zip': No such file or directory
# rm: cannot remove 'resize_data/': No such file or directory

# %%
'''
# 파일이름 resize_data.zip

# %cd /content/keras-yolo3

! pip install gdown
! gdown https://drive.google.com/uc?id=1xnPhd-_OwCsS7ulXjGttYfDuFZccrX0f

# P1 x 40 파일, 파일이름 resize_data.zip 으로 수정 : 2020 11 02 
#https://drive.google.com/file/d/1G8fP26ddYYYQ7qwv0xmEWXdoRLsHWmL8/view?usp=sharing
#https://drive.google.com/file/d/19xArUWBBavTfgpWKZc7m83PfQgGJNLqE/view?usp=sharing

#! mv P1x40_1103.zip resize_data.zip
'''
# Out:
# /content/keras-yolo3
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (3.0.4)
# Downloading...
# From: https://drive.google.com/uc?id=1qtS8Jzrevdwmv1jrJjboAAc31jQ53uJ8
# To: /content/keras-yolo3/resize_data.zip
# 72.1MB [00:00, 229MB/s]

# %%
'''
#zip 압축 파일 풀기 # 파일이름 resize_data.zip

# !mkdir resize_data

# !unzip resize_data.zip -d ./resize_data
'''
# Out:
# Archive:  resize_data.zip
#   inflating: ./resize_data/Annotations/P2--0035.xml
#   inflating: ./resize_data/Annotations/P2--0036.xml
#   inflating: ./resize_data/Annotations/P2--0037.xml
#   inflating: ./resize_data/Annotations/P2--0038.xml
#   inflating: ./resize_data/Annotations/P2--0039.xml
#   inflating: ./resize_data/Annotations/P2--0040.xml
#   inflating: ./resize_data/Annotations/P2--0041.xml
#   inflating: ./resize_data/Annotations/P2--0042.xml
#   inflating: ./resize_data/Annotations/P2--0043.xml
#   inflating: ./resize_data/Annotations/P2--0044.xml
#   inflating: ./resize_data/Annotations/P2--0045.xml
#   inflating: ./resize_data/Annotations/P2--0046.xml
#   inflating: ./resize_data/Annotations/P2--0047.xml
#   inflating: ./resize_data/Annotations/P2--0048.xml
#   inflating: ./resize_data/Annotations/P2--0049.xml
#   inflating: ./resize_data/Annotations/P2--0050.xml
#   inflating: ./resize_data/Annotations/P2--0051.xml
#   inflating: ./resize_data/Annotations/P3--0029.xml
#   inflating: ./resize_data/Annotations/P3--0030.xml
#   inflating: ./resize_data/Annotations/P3--0031.xml
#   inflating: ./resize_data/Annotations/P3--0032.xml
#   inflating: ./resize_data/Annotations/P3--0033.xml
#   inflating: ./resize_data/Annotations/P3--0034.xml
#   inflating: ./resize_data/Annotations/P3--0035.xml
#   inflating: ./resize_data/Annotations/P3--0036.xml
#   inflating: ./resize_data/Annotations/P3--0037.xml
#   inflating: ./resize_data/Annotations/P3--0038.xml
#   inflating: ./resize_data/Annotations/P3--0039.xml
#   inflating: ./resize_data/Annotations/P3--0040.xml
#   inflating: ./resize_data/Annotations/P3--0041.xml
#   inflating: ./resize_data/Annotations/P3--0042.xml
#   inflating: ./resize_data/Annotations/P4-0027.xml
#   inflating: ./resize_data/Annotations/P4-0028.xml
#   inflating: ./resize_data/Annotations/P4-0029.xml
#   inflating: ./resize_data/Annotations/P4-0030.xml
#   inflating: ./resize_data/Annotations/P4-0031.xml
#   inflating: ./resize_data/Annotations/P4-0032.xml
#   inflating: ./resize_data/Annotations/P4-0033.xml
#   inflating: ./resize_data/Annotations/P4-0034.xml
#   inflating: ./resize_data/Annotations/P4-0035.xml
#   inflating: ./resize_data/Annotations/P4-0036.xml
#   inflating: ./resize_data/Annotations/P4-0037.xml
#   inflating: ./resize_data/Annotations/P4-0038.xml
#   inflating: ./resize_data/Annotations/P4-0039.xml
#   inflating: ./resize_data/Annotations/p5-0029.xml
#   inflating: ./resize_data/Annotations/p5-0030.xml
#   inflating: ./resize_data/Annotations/p5-0031.xml
#   inflating: ./resize_data/Annotations/p5-0032.xml
#   inflating: ./resize_data/Annotations/p5-0033.xml
#   inflating: ./resize_data/Annotations/p5-0034.xml
#   inflating: ./resize_data/Annotations/p5-0035.xml
#   inflating: ./resize_data/Annotations/p5-0036.xml
#   inflating: ./resize_data/Annotations/p5-0037.xml
#   inflating: ./resize_data/Annotations/p5-0038.xml
#  extracting: ./resize_data/JPEGImages/p7-0032.jpg
#  extracting: ./resize_data/JPEGImages/p7-0033.jpg
#  extracting: ./resize_data/JPEGImages/p7-0034.jpg
#  extracting: ./resize_data/JPEGImages/p7-0035.jpg
#  extracting: ./resize_data/JPEGImages/p7-0036.jpg
#  extracting: ./resize_data/JPEGImages/p7-0037.jpg
#  extracting: ./resize_data/JPEGImages/p7-0038.jpg
#  extracting: ./resize_data/JPEGImages/p7-0039.jpg
#  extracting: ./resize_data/JPEGImages/p7-0040.jpg
#  extracting: ./resize_data/JPEGImages/p7-0041.jpg
#  extracting: ./resize_data/JPEGImages/p7-0042.jpg
#  extracting: ./resize_data/classes.txt

# %%
# %cd /home/ubuntu/cell/data
# Out:
# [Errno 2] No such file or directory: '/home/ubuntu/cell/data'
# /home/ubuntu/cell/keras-yolo3

# %%
# 압출 풀린 파일들 확인
# !ls -al
# Out:
# 합계 485392
# drwxrwxr-x 9 ubuntu ubuntu      4096  7월 15 18:05 .
# drwxrwxr-x 5 ubuntu ubuntu      4096  7월 22 14:39 ..
# drwxrwxr-x 8 ubuntu ubuntu      4096  7월 15 12:11 .git
# -rw-rw-r-- 1 ubuntu ubuntu      1201  7월 15 12:11 .gitignore
# -rw-rw-r-- 1 ubuntu ubuntu      1064  7월 15 12:11 LICENSE
# -rw-rw-r-- 1 ubuntu ubuntu      4077  7월 15 12:11 README.md
# drwxrwxr-x 2 ubuntu ubuntu      4096  7월 15 18:05 __pycache__
# -rw-rw-r-- 1 ubuntu ubuntu      1323  7월 15 12:11 coco_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu     10093  7월 15 12:11 convert.py
# -rw-rw-r-- 1 ubuntu ubuntu      5707  7월 15 12:11 darknet53.cfg
# drwxrwxr-x 4 ubuntu ubuntu      4096  7월 15 10:55 data-hj
# drwxrwxr-x 5 ubuntu ubuntu      4096  7월 15 15:43 data-yh
# drwxrwxr-x 2 ubuntu ubuntu      4096  7월 15 12:11 font
# -rw-rw-r-- 1 ubuntu ubuntu      3482  7월 15 12:11 kmeans.py
# drwxrwxr-x 2 ubuntu ubuntu      4096  7월 15 12:11 model_data
# -rw-rw-r-- 1 ubuntu ubuntu      8332  7월 15 12:11 train.py
# -rw-rw-r-- 1 ubuntu ubuntu    183955  7월 15 15:56 train_all.txt
# -rw-rw-r-- 1 ubuntu ubuntu     10686  7월 15 12:11 train_bottleneck.py
# -rw-rw-r-- 1 ubuntu ubuntu      1416  7월 15 12:11 voc_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu      8541  7월 15 18:05 yolo.py
# drwxrwxr-x 3 ubuntu ubuntu      4096  7월 15 14:55 yolo3
# -rw-rw-r-- 1 ubuntu ubuntu      2304  7월 15 12:11 yolo_video.py
# -rw-rw-r-- 1 ubuntu ubuntu      1915  7월 15 12:11 yolov3-tiny.cfg
# -rw-rw-r-- 1 ubuntu ubuntu      8342  7월 15 12:11 yolov3.cfg
# -rw-rw-r-- 1 ubuntu ubuntu 248705532  7월 15 14:00 yolov3.h5
# -rw-rw-r-- 1 ubuntu ubuntu 248007048  7월 15 13:55 yolov3.weights

# %% [markdown]
# ## VOC 포멧의 레이블링 데이터를  darknet 포멧으로 변경

# %%
# copy and modified from voc_annotation.py

import xml.etree.ElementTree as ET
from os import getcwd
import glob


def convert_voc_2_darknet(data_folder_name, converted_file_name):
  
  def load_classes():
      with open('%s/classes.txt'%(data_folder_name)) as f:
          classes = f.read().splitlines()

      return classes

  def convert_annotation(image_id, converted_file):
      tree=ET.parse('%s/Annotations/%s.xml'%(data_folder_name, image_id))
      root = tree.getroot()

      for obj in root.iter('object'):
          difficult = obj.find('difficult').text
          cls = obj.find('name').text
          if cls not in classes or int(difficult)==1:
              continue
          cls_id = classes.index(cls)
          xmlbox = obj.find('bndbox')
          b = (int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text))
          converted_file.write(" " + ",".join([str(a) for a in b]) + ',' + str(cls_id))

  # classes = ['tooth', 'decayed', 'cured']
  classes = load_classes()


  # image_ids = ['101', '102', ... '305']
  image_ids = [ f.replace(".xml", "").replace("%s/Annotations/"%(data_folder_name), "") for f in glob.glob('%s/Annotations/*.xml'%(DATA_FOLDER_NAME))]


  wd = getcwd()


  converted_file = open(converted_file_name, 'w')
  for image_id in image_ids:
      converted_file.write('%s/JPEGImages/%s.jpg'%(data_folder_name, image_id))
      convert_annotation(image_id, converted_file)
      converted_file.write('\n')
  converted_file.close()


DATA_FOLDER_NAME = "/home/ubuntu/cell/keras-yolo3/data-yh"
CONVERTED_FILE_NAME = "train_all.txt"

convert_voc_2_darknet(DATA_FOLDER_NAME, CONVERTED_FILE_NAME)

# %%
# !ls -al train_all.txt
# !head -10 train_all.txt
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 180980  7월 15 14:04 train_all.txt
# yh/JPEGImages/P4-0039.jpg 67,56,96,97,4 201,67,237,102,4 183,158,216,216,4 564,191,602,220,4 602,202,625,231,4 650,165,678,217,4 709,172,731,220,4 1076,132,1121,167,4 1132,48,1161,90,4 940,264,987,306,4 812,293,856,335,4 586,246,622,271,4 541,280,588,310,4 521,363,560,410,4 210,461,249,482,4 678,404,731,455,4 1098,449,1122,483,4 977,499,1017,549,4 536,554,580,588,4 585,589,617,611,4 648,612,683,647,4 588,886,636,927,4 985,601,1031,629,4 1014,627,1044,667,4 1058,597,1107,646,4 1165,561,1213,610,4 1009,864,1044,921,4 74,143,128,180,0 384,481,421,515,0 354,499,392,529,0 542,596,581,639,0 691,802,724,841,0 721,605,763,644,0 265,543,310,588,0 221,544,259,599,0 427,903,452,938,0 1171,364,1209,404,0 1065,636,1190,750,3 1173,452,1274,535,3 1214,118,1280,214,3 791,1,933,111,3 1082,192,1226,342,3 1089,893,1194,960,3 513,767,641,866,3 185,849,298,960,3 311,805,397,912,3 29,639,95,746,3 1,322,84,449,3 979,369,1072,430,3 851,786,947,851,3 604,630,710,749,3 448,583,495,622,0
1231,690,2 1103,576,1160,622,5 961,332,1064,397,6 472,855,514,894,0 782,708,840,753,0 290,538,330,624,1 259,586,309,707,1 1206,293,1262,403,6 1180,889,1230,957,1 1206,901,1276,960,1 646,391,677,410,4 669,404,680,421,0 373,292,442,366,2 817,474,889,521,2 597,413,658,471,2 789,385,858,441,2 742,327,786,378,1 903,186,967,277,1 138,318,207,405,2 149,514,219,575,1 503,829,550,866,1 464,712,492,772,1 634,695,730,762,2 741,775,829,853,2 519,63,562,105,2 860,697,958,767,2 1128,324,1181,367,0 809,656,863,714,1 387,439,460,521,2 443,219,462,238,4 430,194,454,258,1 354,688,416,752,2 299,721,365,786,2 478,591,508,618,1

# %%
# !ls
# Out:
# LICENSE		    data-hj	train_all.txt	     yolov3-tiny.cfg
# README.md	    data-yh	train_bottleneck.py  yolov3.cfg
# __pycache__	    font	voc_annotation.py    yolov3.h5
# coco_annotation.py  kmeans.py	yolo.py		     yolov3.weights
# convert.py	    model_data	yolo3
# darknet53.cfg	    train.py	yolo_video.py

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
# %cd /home/ubuntu/cell/keras-yolo3/data-yh/logs/000
# Out:
# /home/ubuntu/cell/keras-yolo3/data-yh/logs/000

# %%
# !ls -al /home/ubuntu/cell/keras-yolo3/data-yh/logs/000
# Out:
# 합계 8219248
# drwxrwxr-x 2 ubuntu ubuntu      4096  7월 22 18:15 .
# drwxr-xr-x 3 ubuntu ubuntu      4096  7월 22 14:49 ..
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 14:57 ep003-loss50556.186-val_loss41274.047.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:03 ep006-loss43430.884-val_loss39298.320.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:09 ep009-loss38383.574-val_loss37372.121.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:15 ep012-loss34776.771-val_loss35948.512.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:21 ep015-loss31595.890-val_loss35144.105.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:27 ep018-loss28910.663-val_loss32818.238.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:33 ep021-loss26512.208-val_loss32241.898.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:40 ep024-loss24471.512-val_loss30723.604.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:46 ep027-loss22556.532-val_loss29814.191.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:52 ep030-loss20988.897-val_loss28419.455.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:58 ep033-loss19408.776-val_loss27305.189.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:04 ep036-loss18122.617-val_loss26701.469.h5
# %%
# !mkdir /home/ubuntu/cell/keras-yolo3/data-yh/logs/000
# Out:
# shell-init: error retrieving current directory: getcwd: 상위 디렉터리에 접근할 수 없음: 그런 파일이나 디렉터리가 없습니다

# %%
# copy and modified from train.py

"""
Retrain the YOLO model for your own dataset.
"""

import numpy as np
import keras.backend as K
from keras.layers import Input, Lambda
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks impo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           rt TensorBoard, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

from yolo3.model import preprocess_true_boxes, yolo_body, tiny_yolo_body, yolo_loss
from yolo3.utils import get_random_data


def _main():
#    annotation_path = 'train.txt'
    annotation_path = '/home/ubuntu/cell/keras-yolo3/train_all.txt' # Modified
    log_dir = '/home/ubuntu/cell/keras-yolo3/data/logs/000/'
#    classes_path = 'model_data/voc_classes.txt' # Modified    
    classes_path = '/home/ubuntu/cell/keras-yolo3/data/classes.txt'
    anchors_path = '/home/ubuntu/cell/keras-yolo3/model_data/yolo_anchors.txt'
    class_names = get_classes(classes_path)
    num_classes = len(class_names)
    anchors = get_anchors(anchors_path)

#----------------------------------------------------------------------- 이미지 사이즈를 수정함 2020 10 12
    #input_shape = (416, 416) # multiple of 32, hw
    input_shape = (1280, 960) # multiple of 32, hw

    is_tiny_version = len(anchors)==6 # default setting
    if is_tiny_version:
        model = create_tiny_model(input_shape, anchors, num_classes,
#            freeze_body=2, weights_path='model_data/tiny_yolo_weights.h5')
            freeze_body=2, weights_path='/home/ubuntu/cell/keras-yolo3/yolov3_tiny.h5') # Modified
    else:
        model = create_model(input_shape, anchors, num_classes,
#            freeze_body=2, weights_path='model_data/yolo_weights.h5')
            freeze_body=2, weights_path='/home/ubuntu/cell/keras-yolo3/yolov3.h5') # Modified

    logging = TensorBoard(log_dir=log_dir)
    checkpoint = ModelCheckpoint(log_dir + 'ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
        monitor='val_loss', save_weights_only=True, save_best_only=True, period=3)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

    val_split = 0.1
    with open(annotation_path) as f:
        lines = f.readlines()
    np.random.seed(10101)
    np.random.shuffle(lines)
    np.random.seed(None)
    num_val = int(len(lines)*val_split)
    num_train = len(lines) - num_val

    # Train with frozen layers first, to get a stable loss.
    # Adjust num epochs to your dataset. This step is enough to obtain a not bad model.
    if True:
        model.compile(optimizer=Adam(lr=1e-3), loss={
            # use custom yolo_loss Lambda layer.
            'yolo_loss': lambda y_true, y_pred: y_pred})

        # batch_size = 32
        batch_size = 16
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
                steps_per_epoch=max(1, num_train//batch_size),
                validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
                validation_steps=max(1, num_val//batch_size),
                epochs=100, #2021 07 15 수정
                initial_epoch=0,
                callbacks=[logging, checkpoint])
        model.save_weights(log_dir + 'trained_weights_stage_1.h5')

    # Unfreeze and continue training, to fine-tune.
    # Train longer if the result is not good.
    if True:
        for i in range(len(model.layers)):
            model.layers[i].trainable = True
        model.compile(optimizer=Adam(lr=1e-4), loss={'yolo_loss': lambda y_true, y_pred: y_pred}) # recompile to apply the change
        print('Unfreeze all of the layers.')

        # batch_size = 32 # note that more GPU memory is required after unfreezing the body
        batch_size = 16 # note that more GPU memory is required after unfreezing the body
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
            steps_per_epoch=max(1, num_train//batch_size),
            validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
            validation_steps=max(1, num_val//batch_size),
            epochs=200,
            initial_epoch=0, #2021 07 15 수정
            callbacks=[logging, checkpoint, reduce_lr, early_stopping])
        model.save_weights(log_dir + 'trained_weights_final.h5')

    # Further training if needed.


def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape(-1, 2)


def create_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
  #          weights_path='model_data/yolo_weights.h5'):
              weights_path='/home/ubuntu/cell/keras-yolo3/yolov3.h5'): # Modified
    '''create the training model'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16, 2:8}[l], w//{0:32, 1:16, 2:8}[l], \
        num_anchors//3, num_classes+5)) for l in range(3)]

    model_body = yolo_body(image_input, num_anchors//3, num_classes)
    print('Create YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze darknet53 body or freeze all but 3 output layers.
            num = (185, len(model_body.layers)-3)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.5})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def create_tiny_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
           # weights_path='model_data/tiny_yolo_weights.h5'):
              weights_path='/home/ubuntu/cell/keras-yolo3/yolov3_tiny.h5'): # modified
    '''create the training model, for Tiny YOLOv3'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16}[l], w//{0:32, 1:16}[l], \
        num_anchors//2, num_classes+5)) for l in range(2)]

    model_body = tiny_yolo_body(image_input, num_anchors//2, num_classes)
    print('Create Tiny YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze the darknet body or freeze all but 2 output layers.
            num = (20, len(model_body.layers)-2)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.7})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes):
    '''data generator for fit_generator'''
    n = len(annotation_lines)
    i = 0
    while True:
        image_data = []
        box_data = []
        for b in range(batch_size):
            if i==0:
                np.random.shuffle(annotation_lines)
            image, box = get_random_data(annotation_lines[i], input_shape, random=True)
            image_data.append(image)
            box_data.append(box)
            i = (i+1) % n
        image_data = np.array(image_data)
        box_data = np.array(box_data)
        y_true = preprocess_true_boxes(box_data, input_shape, anchors, num_classes)
        yield [image_data, *y_true], np.zeros(batch_size)

def data_generator_wrapper(annotation_lines, batch_size, input_shape, anchors, num_classes):
    n = len(annotation_lines)
    if n==0 or batch_size<=0: return None
    return data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes)

_main()
# Out:
# Create YOLOv3 model with 9 anchors and 7 classes.
# Load weights /home/ubuntu/cell/keras-yolo3/yolov3.h5.
# Freeze the first 249 layers of total 252 layers.
# Train on 77 samples, val on 8 samples, with batch size 16.
# Epoch 1/100
# 4/4 [==============================] - 135s 34s/step - loss: 59207.0322 - val_loss: 42646.2305
# Epoch 2/100
# 4/4 [==============================] - 124s 31s/step - loss: 54137.8916 - val_loss: 42118.0586
# Epoch 3/100
# 4/4 [==============================] - 123s 31s/step - loss: 50556.1855 - val_loss: 41274.0469
# Epoch 4/100
# 4/4 [==============================] - 123s 31s/step - loss: 47658.5459 - val_loss: 40978.1914
# Epoch 5/100
# 4/4 [==============================] - 123s 31s/step - loss: 45392.7256 - val_loss: 40162.9102
# Epoch 6/100
# 4/4 [==============================] - 123s 31s/step - loss: 43430.8838 - val_loss: 39298.3203
# Epoch 7/100
# 4/4 [==============================] - 123s 31s/step - loss: 41740.9229 - val_loss: 38765.1484
# Epoch 8/100
# 4/4 [==============================] - 123s 31s/step - loss: 40130.9502 - val_loss: 37606.5664
# Epoch 9/100
# 4/4 [==============================] - 123s 31s/step - loss: 38383.5742 - val_loss: 37372.1211
# Epoch 10/100
# 4/4 [==============================] - 122s 31s/step - loss: 37303.9746 - val_loss: 35921.6211
# Epoch 11/100
# 4/4 [==============================] - 121s 30s/step - loss: 6908.3116 - val_loss: 10792.4551
# Epoch 97/100
# 4/4 [==============================] - 122s 30s/step - loss: 6870.0989 - val_loss: 10602.6133
# Epoch 98/100
# 4/4 [==============================] - 122s 30s/step - loss: 6704.6272 - val_loss: 10689.8916
# Epoch 99/100
# 4/4 [==============================] - 121s 30s/step - loss: 6672.7046 - val_loss: 10293.2969
# Epoch 100/100
# 4/4 [==============================] - 122s 31s/step - loss: 6554.5403 - val_loss: 10473.8662
# Unfreeze all of the layers.
# Train on 77 samples, val on 8 samples, with batch size 16.
# Epoch 1/200

# %%
# !ls -al /home/ubuntu/cell/keras-yolo3/data-yh/logs/000
# Out:
# 합계 8219248
# drwxrwxr-x 2 ubuntu ubuntu      4096  7월 22 18:15 .
# drwxr-xr-x 3 ubuntu ubuntu      4096  7월 22 14:49 ..
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 14:57 ep003-loss50556.186-val_loss41274.047.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:03 ep006-loss43430.884-val_loss39298.320.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:09 ep009-loss38383.574-val_loss37372.121.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:15 ep012-loss34776.771-val_loss35948.512.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:21 ep015-loss31595.890-val_loss35144.105.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:27 ep018-loss28910.663-val_loss32818.238.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:33 ep021-loss26512.208-val_loss32241.898.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:40 ep024-loss24471.512-val_loss30723.604.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:46 ep027-loss22556.532-val_loss29814.191.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:52 ep030-loss20988.897-val_loss28419.455.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 15:58 ep033-loss19408.776-val_loss27305.189.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:04 ep036-loss18122.617-val_loss26701.469.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:11 ep039-loss16991.792-val_loss25352.102.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:17 ep042-loss15895.780-val_loss24545.010.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:23 ep045-loss15098.947-val_loss23217.600.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:29 ep048-loss14128.322-val_loss21942.389.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:35 ep051-loss13400.770-val_loss20991.580.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:41 ep054-loss12713.443-val_loss20507.139.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:47 ep057-loss11911.861-val_loss19437.811.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 16:54 ep060-loss11299.280-val_loss18654.096.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:00 ep063-loss11020.333-val_loss18222.623.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:06 ep066-loss10330.750-val_loss16643.576.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:12 ep069-loss10164.052-val_loss15938.337.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:18 ep072-loss9397.201-val_loss15026.588.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:24 ep075-loss9144.854-val_loss14620.205.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:30 ep078-loss8524.407-val_loss13914.452.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:36 ep081-loss8357.856-val_loss13238.481.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:42 ep084-loss8056.879-val_loss13046.438.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:48 ep087-loss7677.054-val_loss12228.187.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 17:54 ep090-loss7443.059-val_loss11506.335.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 18:01 ep093-loss7176.972-val_loss11144.114.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 18:07 ep096-loss6908.312-val_loss10792.455.h5
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 18:13 ep099-loss6672.705-val_loss10293.297.h5
# -rw-rw-r-- 1 ubuntu ubuntu   5892549  7월 22 18:15 events.out.tfevents.1626933030.ubuntu
# -rw-rw-r-- 1 ubuntu ubuntu  12699727  7월 22 18:15 events.out.tfevents.1626945329.ubuntu
# -rw-rw-r-- 1 ubuntu ubuntu 246996112  7월 22 18:15 trained_weights_stage_1.h5

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %% [markdown]
# ## 물체 탐지 실행

# %%
import tensorflow as tf
from IPython.display import display 
from PIL import Image
from yolo import YOLO

def do_object_detection(file, model_path, class_path):
  
  yolo = YOLO(model_path=model_path, classes_path=class_path)

  # 이미지 로딩
  image = Image.open(file)

  # 실행
  result_image = yolo.detect_image(image)

  # 실행 결과 표시
  display(result_image)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59   from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# ~/anaconda3/envs/cell/lib/python3.7/imp.py in load_module(name, file, filename, details)
#     241         else:
# --> 242             return load_dynamic(name, filename, file)
#     243     elif type_ == PKG_DIRECTORY:
#
# ~/anaconda3/envs/cell/lib/python3.7/imp.py in load_dynamic(name, path, file)
#     341             name=name, loader=loader, origin=path)
# --> 342         return _load(spec)
#     343
#
# ImportError: libcublas.so.10.0: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-7900f19e06e0> in <module>
# ----> 1 import tensorflow as tf
#       2 from IPython.display import display
#       3 from PIL import Image
#       4 from yolo import YOLO
#       5
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 from tensorflow._api.v1 import app
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      47 import numpy as np
#      48
# ---> 49 from tensorflow.python import pywrap_tensorflow
#      50
#      51 # Protocol buffers
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py in <module>
#      72 for some common reasons and solutions.  Include the entire stack trace
#      73 above this error message when asking for help.""" % traceback.format_exc()
# ---> 74   raise ImportError(msg)
#      75
#      76 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
#   File "/home/ubuntu/anaconda3/envs/cell/lib/python3.7/imp.py", line 342, in load_dynamic
#     return _load(spec)
# ImportError: libcublas.so.10.0: cannot open shared object file: No such file or directory
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
#%cd "/content/keras-yolo3"

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')
do_object_detection('/home/ubuntu/cell/keras-yolo3/data-yh/JPEGImages/p6-0039.jpg', \
                    '/home/ubuntu/cell/keras-yolo3/data-yh/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/data-yh/classes.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5c6f37edb37e> in <module>
#       2
#       3 # do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')
# ----> 4 do_object_detection('/home/ubuntu/cell/keras-yolo3/data-yh/JPEGImages/p6-0039.jpg', \
#       5                     '/home/ubuntu/cell/keras-yolo3/data-yh/logs/000/trained_weights_final.h5', \
#       6                     '/home/ubuntu/cell/keras-yolo3/data-yh/classes.txt')
#
# NameError: name 'do_object_detection' is not defined
