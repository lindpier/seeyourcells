# %% [markdown]
# # 물체 탐지(Object Detection)
# #.0## 2021 10 20 (crop to 4 하여 데이터 증강)

# %%
# !pip3 install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (0.37.0)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-win_amd64.whl (13.9 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.0-py2.py3-none-any.whl (156 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\msi\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\msi\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\msi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\msi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\msi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\msi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=fe5523c533b1272d8bf7680b5bb0e98bf199d451e2f50ae80d1244d569fc8e0e
#   Stored in directory: c:\users\msi\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 flatbuffers-2.0 gast-0.4.0 google-auth-2.6.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 keras-2.7.0 keras-preprocessing-1.1.2 libclang-13.0.0 markdown-3.3.6 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.23.1 termcolor-1.1.0

# %%
import tensorflow

# %%
# !pip3 uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Successfully uninstalled tensorflow-2.7.0
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\commands\uninstall.py", line 97, in run
#     uninstall_pathset.commit()
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\req\req_uninstall.py", line 436, in commit
#     self._moved_paths.commit()
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\req\req_uninstall.py", line 287, in commit
#     save_dir.cleanup()
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\utils\temp_dir.py", line 184, in cleanup
#     rmtree(self._path)
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 326, in wrapped_f
#     return self(f, *args, **kw)
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 406, in __call__
#     do = self.iter(retry_state=retry_state)
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 362, in iter
#     raise retry_exc.reraise()
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 195, in reraise
#     raise self.last_attempt.result()
#   File "C:\Users\MSI\anaconda3\lib\concurrent\futures\_base.py", line 438, in result
#     return self.__get_result()
#   File "C:\Users\MSI\anaconda3\lib\concurrent\futures\_base.py", line 390, in __get_result
#     raise self._exception
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_vendor\tenacity\__init__.py", line 409, in __call__
#     result = fn(*args, **kwargs)
#   File "C:\Users\MSI\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 135, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors, onerror=rmtree_errorhandler)
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 748, in rmtree
#     return _rmtree_unsafe(path, onerror)
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 621, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 621, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 621, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   [Previous line repeated 2 more times]
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 626, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "C:\Users\MSI\anaconda3\lib\shutil.py", line 624, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\MSI\\anaconda3\\Lib\\site-packages\\~ensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'

# %%
# !conda install tensorflow-gpu==1.13.1
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining tensorflow-gpu==1.13.1:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__cuda==11.2=0:  20%|##        | 1/5 [00:00<00:00, 1025.50it/s]
# Examining @/win-64::__archspec==1=x86_64:  40%|####      | 2/5 [00:00<00:00, 2051.00it/s]
# Examining python=3.9:  60%|######    | 3/5 [00:00<00:00, 3076.51it/s]
# Examining @/win-64::__win==0=0:  80%|########  | 4/5 [00:00<00:00, 89.28it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for python tensorflow-gpu:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - tensorflow-gpu==1.13.1 -> python[version='3.6.*|3.7.*']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
# !pip install tensorflow==1.13.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.13.1 (from versions: 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.8.0rc0, 2.8.0rc1)
# ERROR: No matching distribution found for tensorflow==1.13.1

# %%
# !pip3 install keras==2.1.6
# Out:
# Collecting keras==2.1.6
#   Downloading Keras-2.1.6-py2.py3-none-any.whl (339 kB)
# Requirement already satisfied: scipy>=0.14 in c:\users\msi\anaconda3\lib\site-packages (from keras==2.1.6) (1.7.1)
# Requirement already satisfied: pyyaml in c:\users\msi\anaconda3\lib\site-packages (from keras==2.1.6) (6.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\msi\anaconda3\lib\site-packages (from keras==2.1.6) (1.16.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\msi\anaconda3\lib\site-packages (from keras==2.1.6) (1.20.3)
# Requirement already satisfied: h5py in c:\users\msi\anaconda3\lib\site-packages (from keras==2.1.6) (3.2.1)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
# Successfully installed keras-2.1.6

# %%
# !pip3 install h5py==2.10.0
# Out:
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0.tar.gz (301 kB)
# Requirement already satisfied: numpy>=1.7 in c:\users\msi\anaconda3\lib\site-packages (from h5py==2.10.0) (1.20.3)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\MSI\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\MSI\\AppData\\Local\\Temp\\pip-install-p6gzk9n4\\h5py_3f0165b17a874ec28c5c543a1a59c0f2\\setup.py'"'"'; __file__='"'"'C:\\Users\\MSI\\AppData\\Local\\Temp\\pip-install-p6gzk9n4\\h5py_3f0165b17a874ec28c5c543a1a59c0f2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\MSI\AppData\Local\Temp\pip-wheel-mh9k99rv'
#        cwd: C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\
#   Complete output (1312 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\h5py
#   copying h5py\h5py_warnings.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\highlevel.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\ipy_completer.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\version.py -> build\lib.win-amd64-3.9\h5py
#   copying h5py\__init__.py -> build\lib.win-amd64-3.9\h5py
#   creating build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\attrs.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\base.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\compat.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\dataset.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\datatype.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\dims.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\files.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\filters.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\group.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\selections.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\selections2.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\vds.py -> build\lib.win-amd64-3.9\h5py\_hl
#   copying h5py\_hl\__init__.py -> build\lib.win-amd64-3.9\h5py\_hl
#   creating build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\common.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attribute_create.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attrs.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_attrs_data.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_base.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_completions.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset_getitem.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dataset_swmr.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_datatype.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_deprecation.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dimension_scales.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dims_dimensionproxy.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_dtype.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file2.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_file_image.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_filters.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_group.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5d_direct_chunk.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5f.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5p.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5pl.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_h5t.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_objects.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_selections.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_slicing.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\test_threads.py -> build\lib.win-amd64-3.9\h5py\tests
#   copying h5py\tests\__init__.py -> build\lib.win-amd64-3.9\h5py\tests
#   creating build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_highlevel_vds.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_lowlevel_vds.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\test_virtual_source.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   copying h5py\tests\test_vds\__init__.py -> build\lib.win-amd64-3.9\h5py\tests\test_vds
#   running build_ext
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
# Requirement already satisfied: six in c:\users\msi\anaconda3\lib\site-packages (from h5py==2.10.0) (1.16.0)
# Building wheels for collected packages: h5py
#   Building wheel for h5py (setup.py): started
#   Building wheel for h5py (setup.py): finished with status 'error'
#   Running setup.py clean for h5py
# Failed to build h5py
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.2.1
#     Uninstalling h5py-3.2.1:
#       Successfully uninstalled h5py-3.2.1
#     Running setup.py install for h5py: started
#     Running setup.py install for h5py: finished with status 'error'
#   Rolling back uninstall of h5py
#   Moving to c:\users\msi\anaconda3\lib\site-packages\h5py-3.2.1.dist-info\
#    from C:\Users\MSI\anaconda3\Lib\site-packages\~5py-3.2.1.dist-info
#   Moving to c:\users\msi\anaconda3\lib\site-packages\h5py\
#    from C:\Users\MSI\anaconda3\Lib\site-packages\~5py
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#   warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#   warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#   warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#   warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#   warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#   warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#   warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#   warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#   warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#   warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#   warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#   warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#   warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#   warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#   warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#   warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#   warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#   warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#   warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#   warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#   warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#   warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#   warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#   warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#   warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#   warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#   warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
# ...
#     warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#     warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#     warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#     warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#     warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#     warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#     warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#     warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#     warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#     warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#     warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#     warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#     warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#     warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#     warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#     warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#     warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#     warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#     warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#     warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#     warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:418:2: 'H5D_layout_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:425:2: 'H5D_alloc_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:432:2: 'H5D_space_status_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:438:2: 'H5D_fill_time_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:444:2: 'H5D_fill_value_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:456:7: 'H5F_close_degree_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:462:2: 'H5FD_mem_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:560:2: 'H5T_cset_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:739:7: 'H5Z_EDC_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:419:4: 'H5D_LAYOUT_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:420:4: 'H5D_COMPACT' redeclared
#     warning: h5py\api_types_hdf5.pxd:421:4: 'H5D_CONTIGUOUS' redeclared
#     warning: h5py\api_types_hdf5.pxd:422:4: 'H5D_CHUNKED' redeclared
#     warning: h5py\api_types_hdf5.pxd:423:4: 'H5D_NLAYOUTS' redeclared
#     warning: h5py\api_types_hdf5.pxd:426:4: 'H5D_ALLOC_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:427:4: 'H5D_ALLOC_TIME_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:428:4: 'H5D_ALLOC_TIME_EARLY' redeclared
#     warning: h5py\api_types_hdf5.pxd:429:4: 'H5D_ALLOC_TIME_LATE' redeclared
#     warning: h5py\api_types_hdf5.pxd:430:4: 'H5D_ALLOC_TIME_INCR' redeclared
#     warning: h5py\api_types_hdf5.pxd:433:4: 'H5D_SPACE_STATUS_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:434:4: 'H5D_SPACE_STATUS_NOT_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:435:4: 'H5D_SPACE_STATUS_PART_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:436:4: 'H5D_SPACE_STATUS_ALLOCATED' redeclared
#     warning: h5py\api_types_hdf5.pxd:439:4: 'H5D_FILL_TIME_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:440:4: 'H5D_FILL_TIME_ALLOC' redeclared
#     warning: h5py\api_types_hdf5.pxd:441:4: 'H5D_FILL_TIME_NEVER' redeclared
#     warning: h5py\api_types_hdf5.pxd:442:4: 'H5D_FILL_TIME_IFSET' redeclared
#     warning: h5py\api_types_hdf5.pxd:445:4: 'H5D_FILL_VALUE_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:446:4: 'H5D_FILL_VALUE_UNDEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:447:4: 'H5D_FILL_VALUE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:448:4: 'H5D_FILL_VALUE_USER_DEFINED' redeclared
#     warning: h5py\api_types_hdf5.pxd:457:4: 'H5F_CLOSE_WEAK' redeclared
#     warning: h5py\api_types_hdf5.pxd:458:4: 'H5F_CLOSE_SEMI' redeclared
#     warning: h5py\api_types_hdf5.pxd:459:4: 'H5F_CLOSE_STRONG' redeclared
#     warning: h5py\api_types_hdf5.pxd:460:4: 'H5F_CLOSE_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:463:4: 'H5FD_MEM_NOLIST' redeclared
#     warning: h5py\api_types_hdf5.pxd:464:4: 'H5FD_MEM_DEFAULT' redeclared
#     warning: h5py\api_types_hdf5.pxd:465:4: 'H5FD_MEM_SUPER' redeclared
#     warning: h5py\api_types_hdf5.pxd:466:4: 'H5FD_MEM_BTREE' redeclared
#     warning: h5py\api_types_hdf5.pxd:467:4: 'H5FD_MEM_DRAW' redeclared
#     warning: h5py\api_types_hdf5.pxd:468:4: 'H5FD_MEM_GHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:469:4: 'H5FD_MEM_LHEAP' redeclared
#     warning: h5py\api_types_hdf5.pxd:470:4: 'H5FD_MEM_OHDR' redeclared
#     warning: h5py\api_types_hdf5.pxd:471:4: 'H5FD_MEM_NTYPES' redeclared
#     warning: h5py\api_types_hdf5.pxd:561:4: 'H5T_CSET_ERROR' redeclared
#     warning: h5py\api_types_hdf5.pxd:562:4: 'H5T_CSET_ASCII' redeclared
#     warning: h5py\api_types_hdf5.pxd:705:2: 'H5Z_filter_t' redeclared
#     warning: h5py\api_types_hdf5.pxd:740:6: 'H5Z_ERROR_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:741:6: 'H5Z_DISABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:742:6: 'H5Z_ENABLE_EDC' redeclared
#     warning: h5py\api_types_hdf5.pxd:743:6: 'H5Z_NO_EDC' redeclared
#     Loading library to get version: hdf5.dll
#     Autodetected HDF5 1.10.6
#     ********************************************************************************
#                            Summary of the h5py configuration
#
#         Path to HDF5: None
#         HDF5 Version: '1.10.6'
#          MPI Enabled: False
#     Rebuild Required: True
#
#     ********************************************************************************
#     Executing cythonize()
#     [ 1/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\_conv.pyx
#     [ 2/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\_errors.pyx
#     [ 3/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\_objects.pyx
#     [ 4/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\_proxy.pyx
#     [ 5/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\defs.pyx
#     [ 6/23] Cythonizing C:\Users\MSI\AppData\Local\Temp\pip-install-p6gzk9n4\h5py_3f0165b17a874ec28c5c543a1a59c0f2\h5py\h5.pyx
anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\MSI\\AppData\\Local\\Temp\\pip-install-p6gzk9n4\\h5py_3f0165b17a874ec28c5c543a1a59c0f2\\setup.py'"'"'; __file__='"'"'C:\\Users\\MSI\\AppData\\Local\\Temp\\pip-install-p6gzk9n4\\h5py_3f0165b17a874ec28c5c543a1a59c0f2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\MSI\AppData\Local\Temp\pip-record-c0sm56sf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\MSI\anaconda3\Include\h5py' Check the logs for full command output.

# %%
# !pip3 uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:
#   Successfully uninstalled tensorflow-2.6.0

# %%
# !conda install tensorflow==1.13.1
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining python=3.9:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__win==0=0:  20%|##        | 1/5 [00:00<00:00, 22.80it/s]
# Examining @/win-64::__cuda==11.2=0:  40%|####      | 2/5 [00:00<00:00, 45.61it/s]
# Examining tensorflow==1.13.1:  60%|######    | 3/5 [00:00<00:00, 68.41it/s]
# Examining @/win-64::__archspec==1=x86_64:  80%|########  | 4/5 [00:00<00:00, 72.97it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for tensorflow python:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - tensorflow==1.13.1 -> python[version='3.6.*|3.7.*']
#   - tensorflow==1.13.1 -> python[version='>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
# !pip3 uninstall -y keras
# !pip3 uninstall keras -nightly
# !pip3 uninstall -y tensorflow-gpu
# !pip3 uninstall tensorflow-gpu -nightly

# !pip3 install keras==2.1.6
# !pip3 install tensorflow-gpu==1.13.1
# !pip3 install h5py==2.10.0
# Out:
# Found existing installation: Keras 2.1.6
# Uninstalling Keras-2.1.6:
#   Successfully uninstalled Keras-2.1.6
#
# Usage:
#   pip3 uninstall [options] <package> ...
#   pip3 uninstall [options] -r <requirements file> ...
#
# no such option: -n
# WARNING: Skipping tensorflow-gpu as it is not installed.
#
# Usage:
#   pip3 uninstall [options] <package> ...
#   pip3 uninstall [options] -r <requirements file> ...
#
# no such option: -n
# Collecting keras==2.1.6
#   Using cached Keras-2.1.6-py2.py3-none-any.whl (339 kB)
# Requirement already satisfied: pyyaml in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (5.4.1)
# Requirement already satisfied: scipy>=0.14 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.6.2)
# Requirement already satisfied: numpy>=1.9.1 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.19.5)
# Requirement already satisfied: h5py in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.15.0)
# Installing collected packages: keras
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires h5py~=3.1.0, but you have h5py 2.10.0 which is incompatible.
# tensorflow 2.6.0 requires keras~=2.6, but you have keras 2.1.6 which is incompatible.
# Successfully installed keras-2.1.6
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==1.13.1
# ERROR: No matching distribution found for tensorflow-gpu==1.13.1
# Requirement already satisfied: h5py==2.10.0 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: six in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from h5py==2.10.0) (1.19.5)

# %%
import keras
print(keras.__version__)
# Out:
# 2.7.0

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.7.0

# %%
# !pip3 uninstall -y keras==2.6.0
# Out:
# WARNING: Skipping keras as it is not installed.

# %%
# !pip3 install keras==2.1.6
# Out:
# Collecting keras==2.1.6
#   Using cached Keras-2.1.6-py2.py3-none-any.whl (339 kB)
# Requirement already satisfied: pyyaml in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (5.4.1)
# Requirement already satisfied: six>=1.9.0 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.15.0)
# Requirement already satisfied: h5py in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /home/ubuntu/anaconda3/lib/python3.8/site-packages (from keras==2.1.6) (1.6.2)
# Installing collected packages: keras
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires h5py~=3.1.0, but you have h5py 2.10.0 which is incompatible.
# tensorflow 2.6.0 requires keras~=2.6, but you have keras 2.1.6 which is incompatible.
# Successfully installed keras-2.1.6

# %% [markdown]
# ## Darknet 준비

# %%
# 프로젝트 다운로드
# %cd /content
# !rm -rf darknet
# !git clone https://github.com/pjreddie/darknet
# Out:
# /content
# Cloning into 'darknet'...
# remote: Enumerating objects: 5937, done.
# remote: Total 5937 (delta 0), reused 0 (delta 0), pack-reused 5937
# Receiving objects: 100% (5937/5937), 6.35 MiB | 24.25 MiB/s, done.
# Resolving deltas: 100% (3926/3926), done.

# %%
# 빌드
# %cd /content/darknet
# !make

# 빌드된 실행파일 확인
# !ls -al darknet

# 빌드 확인
# !./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/network.c -o obj/network.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/parser.c -o obj/parser.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/logistic_layer.c -o obj/logistic_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/l2norm_layer.c -o obj/l2norm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/yolo_layer.c -o obj/yolo_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/iseg_layer.c -o obj/iseg_layer.o
# g++ -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# gcc -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -shared obj/gemm.o obj/utils.o obj/cuda.o obj/deconvolutional_layer.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/detection_layer.o obj/route_layer.o obj/upsample_layer.o obj/box.o obj/normalization_layer.o obj/avgpool_layer.o obj/layer.o obj/local_layer.o obj/shortcut_layer.o obj/logistic_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/crnn_layer.o obj/demo.o obj/batchnorm_layer.o obj/region_layer.o obj/reorg_layer.o obj/tree.o obj/lstm_layer.o obj/l2norm_layer.o obj/yolo_layer.o obj/iseg_layer.o obj/image_opencv.o -o libdarknet.so -lm -pthread
# ar rcs libdarknet.a obj/gemm.o obj/utils.o obj/cuda.o obj/deconvolutional_layer.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/detection_layer.o obj/route_layer.o obj/upsample_layer.o obj/box.o obj/normalization_layer.o obj/avgpool_layer.o obj/layer.o obj/local_layer.o obj/shortcut_layer.o obj/logistic_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/crnn_layer.o obj/demo.o obj/batchnorm_layer.o obj/region_layer.o obj/reorg_layer.o obj/tree.o obj/lstm_layer.o obj/l2norm_layer.o obj/yolo_layer.o obj/iseg_layer.o obj/image_opencv.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/lsd.c -o obj/lsd.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/super.c -o obj/super.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/art.c -o obj/art.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/tag.c -o obj/tag.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/go.c -o obj/go.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/segmenter.c -o obj/segmenter.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/regressor.c -o obj/regressor.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/coco.c -o obj/coco.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/detector.c -o obj/detector.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/instance-segmenter.c -o obj/instance-segmenter.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./examples/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast obj/captcha.o obj/lsd.o obj/super.o obj/art.o obj/tag.o obj/cifar.o obj/go.o obj/rnn.o obj/segmenter.o obj/regressor.o obj/classifier.o obj/coco.o obj/yolo.o obj/detector.o obj/nightmare.o obj/instance-segmenter.o obj/darknet.o libdarknet.a -o darknet -lm -pthread  libdarknet.a
# -rwxr-xr-x 1 root root 730568 Jul 26 05:25 darknet
# usage: ./darknet <function>

# %% [markdown]
# ## 학습된 모델 파일 다운로드

# %%
# %cd /content/darknet
# !wget wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# /content/darknet
# --2021-07-26 05:25:53--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2021-07-26 05:25:53--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  47.2MB/s    in 5.3s
#
# 2021-07-26 05:25:59 (45.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# FINISHED --2021-07-26 05:25:59--
# Total wall clock time: 5.6s
# Downloaded: 1 files, 237M in 5.3s (45.0 MB/s)

# %% [markdown]
# ## Keras 변환 코드 다운로드

# %%
# 다운로드
# %cd //home/ubuntu/cell
# !rm -rf keras-yolo3

# !git clone https://github.com/qqwweee/keras-yolo3
  
# 다운로드된 디렉토리로 이동
# %cd keras-yolo3

# 내용 확인
# !pwd
# !ls -al
# Out:
# /home/ubuntu/cell
# 'keras-yolo3'에 복제합니다...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# 오브젝트를 받는 중: 100% (144/144), 151.08 KiB | 894.00 KiB/s, 완료.
# 델타를 알아내는 중: 100% (65/65), 완료.
# /home/ubuntu/cell/keras-yolo3
# /home/ubuntu/cell/keras-yolo3
# 합계 124
# drwxrwxr-x 6 ubuntu ubuntu  4096  8월 19 15:03 .
# drwxrwxr-x 6 ubuntu ubuntu  4096  8월 19 15:03 ..
# drwxrwxr-x 8 ubuntu ubuntu  4096  8월 19 15:03 .git
# -rw-rw-r-- 1 ubuntu ubuntu  1201  8월 19 15:03 .gitignore
# -rw-rw-r-- 1 ubuntu ubuntu  1064  8월 19 15:03 LICENSE
# -rw-rw-r-- 1 ubuntu ubuntu  4077  8월 19 15:03 README.md
# -rw-rw-r-- 1 ubuntu ubuntu  1323  8월 19 15:03 coco_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu 10093  8월 19 15:03 convert.py
# -rw-rw-r-- 1 ubuntu ubuntu  5707  8월 19 15:03 darknet53.cfg
# drwxrwxr-x 2 ubuntu ubuntu  4096  8월 19 15:03 font
# -rw-rw-r-- 1 ubuntu ubuntu  3482  8월 19 15:03 kmeans.py
# drwxrwxr-x 2 ubuntu ubuntu  4096  8월 19 15:03 model_data
# -rw-rw-r-- 1 ubuntu ubuntu  8332  8월 19 15:03 train.py
# -rw-rw-r-- 1 ubuntu ubuntu 10686  8월 19 15:03 train_bottleneck.py
# -rw-rw-r-- 1 ubuntu ubuntu  1416  8월 19 15:03 voc_annotation.py
# -rw-rw-r-- 1 ubuntu ubuntu  8540  8월 19 15:03 yolo.py
# drwxrwxr-x 2 ubuntu ubuntu  4096  8월 19 15:03 yolo3
# -rw-rw-r-- 1 ubuntu ubuntu  2304  8월 19 15:03 yolo_video.py
# -rw-rw-r-- 1 ubuntu ubuntu  1915  8월 19 15:03 yolov3-tiny.cfg
# -rw-rw-r-- 1 ubuntu ubuntu  8342  8월 19 15:03 yolov3.cfg

# %%
# 다운로드

# %cd C:\Users\MSI\YOLO\keras-yolo3
# Out:
# C:\Users\MSI\YOLO\keras-yolo3

# %%
# %cd keras-yolo3
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'keras-yolo3'
# C:\Users\MSI\YOLO

# %%
git clone https://github.com/qqwweee/keras-yolo3
# Out:
#   File "C:\Users\MSI\AppData\Local\Temp/ipykernel_19136/2771977956.py", line 1
#     git clone https://github.com/qqwweee/keras-yolo3
#         ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/qqwweee/keras-yolo3
  
# 다운로드된 디렉토리로 이동
# %cd keras-yolo3

# 내용 확인
# !pwd
# !ls -al

# %% [markdown]
# ## YOLO3 모델 파일 카피

# %%
# %cd /content/keras-yolo3

# !cp /content/darknet/yolov3.weights ./

# !ls -al yolov3.weights
# Out:
# /content/keras-yolo3
# -rw-r--r-- 1 root root 248007048 Jul 26 05:26 yolov3.weights

# %% [markdown]
# ## 모델 파일 변환
#
# YOLO3 자체는 C/C++로 구현된 DarkNet 프레임웤으로 구현되어 있다.
#
# 공개된 모델은 DarkNet의 포멧이다. 이를 Keras에서 사용할 수 있는 h5 포멧으로 변환한다.
#
#
# - convert.py : 변환 실행 파일
#
# - yolov3.cfg : Darknet에서 사용하는 모델 구조 정의 파일
#
# - yolov3.weight : Darknet으로 학습된 모델 파일
#
#
# 실행 결과로 다음의 h5 파일로 변환된다.
#
# - model/yolov3.h5 : 변환된 모델 파일

# %%
# !head -40 yolov3.cfg
# Out:
# [net]
# # Testing
# batch=1
# subdivisions=1
# # Training
# # batch=64
# # subdivisions=16
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 500200
# policy=steps
# steps=400000,450000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1

# %%
'''
#tiny  추가 (송미경 수정)
# 실행하기전 기존것이 있다면 삭제

# !rm -rf yolov3-tiny.h5

# 실행 
# %run convert.py yolov3-tiny.cfg yolov3.weights yolov3-tiny.h5
'''
# Out:
# ERROR:root:File `'convert.py'` not found.

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
# 실행하기전 기존것이 있다면 삭제
# !rm -rf yolov3.h5

# %%
# 실행 
# %run convert.py yolov3.cfg yolov3.weights yolov3.h5
# Out:
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 36)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_107/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_1242/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 36)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_108/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_1234/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 36)
# Parsing section yolo_2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_62 (InputLayer)           (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_3999 (Conv2D)            (None, None, None, 3 864         input_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3836 (Batch (None, None, None, 3 128         conv2d_3999[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3836 (LeakyReLU)    (None, None, None, 3 0           batch_normalization_3836[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_271 (ZeroPadding (None, None, None, 3 0           leaky_re_lu_3836[0][0]
# __________________________________________________________________________________________________
# conv2d_4000 (Conv2D)            (None, None, None, 6 18432       zero_padding2d_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3837 (Batch (None, None, None, 6 256         conv2d_4000[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3837 (LeakyReLU)    (None, None, None, 6 0           batch_normalization_3837[0][0]
# __________________________________________________________________________________________________
# conv2d_4001 (Conv2D)            (None, None, None, 3 2048        leaky_re_lu_3837[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3838 (Batch (None, None, None, 3 128         conv2d_4001[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3838 (LeakyReLU)    (None, None, None, 3 0           batch_normalization_3838[0][0]
# __________________________________________________________________________________________________
# conv2d_4002 (Conv2D)            (None, None, None, 6 18432       leaky_re_lu_3838[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3839 (Batch (None, None, None, 6 256         conv2d_4002[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3839 (LeakyReLU)    (None, None, None, 6 0           batch_normalization_3839[0][0]
# __________________________________________________________________________________________________
# add_1224 (Add)                  (None, None, None, 6 0           leaky_re_lu_3837[0][0]
#                                                                  leaky_re_lu_3839[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_272 (ZeroPadding (None, None, None, 6 0           add_1224[0][0]
# __________________________________________________________________________________________________
# conv2d_4003 (Conv2D)            (None, None, None, 1 73728       zero_padding2d_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3840 (Batch (None, None, None, 1 512         conv2d_4003[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3840 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3840[0][0]
# __________________________________________________________________________________________________
# conv2d_4004 (Conv2D)            (None, None, None, 6 8192        leaky_re_lu_3840[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3841 (Batch (None, None, None, 6 256         conv2d_4004[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3841 (LeakyReLU)    (None, None, None, 6 0           batch_normalization_3841[0][0]
# __________________________________________________________________________________________________
# conv2d_4005 (Conv2D)            (None, None, None, 1 73728       leaky_re_lu_3841[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3842 (Batch (None, None, None, 1 512         conv2d_4005[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3842 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3842[0][0]
# __________________________________________________________________________________________________
# add_1225 (Add)                  (None, None, None, 1 0           leaky_re_lu_3840[0][0]
#                                                                  leaky_re_lu_3842[0][0]
# __________________________________________________________________________________________________
# conv2d_4006 (Conv2D)            (None, None, None, 6 8192        add_1225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3843 (Batch (None, None, None, 6 256         conv2d_4006[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3843 (LeakyReLU)    (None, None, None, 6 0           batch_normalization_3843[0][0]
# __________________________________________________________________________________________________
# conv2d_4007 (Conv2D)            (None, None, None, 1 73728       leaky_re_lu_3843[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3844 (Batch (None, None, None, 1 512         conv2d_4007[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3844 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3844[0][0]
# __________________________________________________________________________________________________
# add_1226 (Add)                  (None, None, None, 1 0           add_1225[0][0]
#                                                                  leaky_re_lu_3844[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_273 (ZeroPadding (None, None, None, 1 0           add_1226[0][0]
# __________________________________________________________________________________________________
# conv2d_4008 (Conv2D)            (None, None, None, 2 294912      zero_padding2d_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3845 (Batch (None, None, None, 2 1024        conv2d_4008[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3845 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3845[0][0]
# __________________________________________________________________________________________________
# conv2d_4009 (Conv2D)            (None, None, None, 1 32768       leaky_re_lu_3845[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3846 (Batch (None, None, None, 1 512         conv2d_4009[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3846 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3846[0][0]
# __________________________________________________________________________________________________
# conv2d_4010 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3846[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3847 (Batch (None, None, None, 2 1024        conv2d_4010[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3847 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3847[0][0]
# __________________________________________________________________________________________________
# add_1227 (Add)                  (None, None, None, 2 0           leaky_re_lu_3845[0][0]
#                                                                  leaky_re_lu_3847[0][0]
# __________________________________________________________________________________________________
# conv2d_4011 (Conv2D)            (None, None, None, 1 32768       add_1227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3848 (Batch (None, None, None, 1 512         conv2d_4011[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3848 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3848[0][0]
# __________________________________________________________________________________________________
# conv2d_4012 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3848[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3849 (Batch (None, None, None, 2 1024        conv2d_4012[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3849 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3849[0][0]
# __________________________________________________________________________________________________
# add_1228 (Add)                  (None, None, None, 2 0           add_1227[0][0]
#                                                                  leaky_re_lu_3849[0][0]
# __________________________________________________________________________________________________
# conv2d_4013 (Conv2D)            (None, None, None, 1 32768       add_1228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3850 (Batch (None, None, None, 1 512         conv2d_4013[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3850 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3850[0][0]
# __________________________________________________________________________________________________
# conv2d_4014 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3850[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3851 (Batch (None, None, None, 2 1024        conv2d_4014[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3851 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3851[0][0]
# __________________________________________________________________________________________________
# add_1229 (Add)                  (None, None, None, 2 0           add_1228[0][0]
#                                                                  leaky_re_lu_3851[0][0]
# __________________________________________________________________________________________________
# conv2d_4015 (Conv2D)            (None, None, None, 1 32768       add_1229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3852 (Batch (None, None, None, 1 512         conv2d_4015[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3852 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3852[0][0]
# __________________________________________________________________________________________________
# conv2d_4016 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3852[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3853 (Batch (None, None, None, 2 1024        conv2d_4016[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3853 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3853[0][0]
# __________________________________________________________________________________________________
# add_1230 (Add)                  (None, None, None, 2 0           add_1229[0][0]
#                                                                  leaky_re_lu_3853[0][0]
# __________________________________________________________________________________________________
# conv2d_4017 (Conv2D)            (None, None, None, 1 32768       add_1230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3854 (Batch (None, None, None, 1 512         conv2d_4017[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3854 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3854[0][0]
# __________________________________________________________________________________________________
# conv2d_4018 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3854[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3855 (Batch (None, None, None, 2 1024        conv2d_4018[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3855 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3855[0][0]
# __________________________________________________________________________________________________
# add_1231 (Add)                  (None, None, None, 2 0           add_1230[0][0]
#                                                                  leaky_re_lu_3855[0][0]
# __________________________________________________________________________________________________
# conv2d_4019 (Conv2D)            (None, None, None, 1 32768       add_1231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3856 (Batch (None, None, None, 1 512         conv2d_4019[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3856 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3856[0][0]
# __________________________________________________________________________________________________
# conv2d_4020 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3856[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3857 (Batch (None, None, None, 2 1024        conv2d_4020[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3857 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3857[0][0]
# __________________________________________________________________________________________________
# add_1232 (Add)                  (None, None, None, 2 0           add_1231[0][0]
#                                                                  leaky_re_lu_3857[0][0]
# __________________________________________________________________________________________________
# conv2d_4021 (Conv2D)            (None, None, None, 1 32768       add_1232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3858 (Batch (None, None, None, 1 512         conv2d_4021[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3858 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3858[0][0]
# __________________________________________________________________________________________________
# conv2d_4022 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3858[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3859 (Batch (None, None, None, 2 1024        conv2d_4022[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3859 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3859[0][0]
# __________________________________________________________________________________________________
# add_1233 (Add)                  (None, None, None, 2 0           add_1232[0][0]
#                                                                  leaky_re_lu_3859[0][0]
# __________________________________________________________________________________________________
# conv2d_4023 (Conv2D)            (None, None, None, 1 32768       add_1233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3860 (Batch (None, None, None, 1 512         conv2d_4023[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3860 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3860[0][0]
# __________________________________________________________________________________________________
# conv2d_4024 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3860[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3861 (Batch (None, None, None, 2 1024        conv2d_4024[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3861 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3861[0][0]
# __________________________________________________________________________________________________
# add_1234 (Add)                  (None, None, None, 2 0           add_1233[0][0]
#                                                                  leaky_re_lu_3861[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_274 (ZeroPadding (None, None, None, 2 0           add_1234[0][0]
# __________________________________________________________________________________________________
# conv2d_4025 (Conv2D)            (None, None, None, 5 1179648     zero_padding2d_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3862 (Batch (None, None, None, 5 2048        conv2d_4025[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3862 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3862[0][0]
# __________________________________________________________________________________________________
# conv2d_4026 (Conv2D)            (None, None, None, 2 131072      leaky_re_lu_3862[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3863 (Batch (None, None, None, 2 1024        conv2d_4026[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3863 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3863[0][0]
# __________________________________________________________________________________________________
# conv2d_4027 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3863[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3864 (Batch (None, None, None, 5 2048        conv2d_4027[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3864 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3864[0][0]
# __________________________________________________________________________________________________
# add_1235 (Add)                  (None, None, None, 5 0           leaky_re_lu_3862[0][0]
#                                                                  leaky_re_lu_3864[0][0]
# __________________________________________________________________________________________________
# conv2d_4028 (Conv2D)            (None, None, None, 2 131072      add_1235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3865 (Batch (None, None, None, 2 1024        conv2d_4028[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3865 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3865[0][0]
# __________________________________________________________________________________________________
# conv2d_4029 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3865[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3866 (Batch (None, None, None, 5 2048        conv2d_4029[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3866 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3866[0][0]
# __________________________________________________________________________________________________
# add_1236 (Add)                  (None, None, None, 5 0           add_1235[0][0]
#                                                                  leaky_re_lu_3866[0][0]
# __________________________________________________________________________________________________
# conv2d_4030 (Conv2D)            (None, None, None, 2 131072      add_1236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3867 (Batch (None, None, None, 2 1024        conv2d_4030[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3867 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3867[0][0]
# __________________________________________________________________________________________________
# conv2d_4031 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3867[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3868 (Batch (None, None, None, 5 2048        conv2d_4031[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3868 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3868[0][0]
# __________________________________________________________________________________________________
# add_1237 (Add)                  (None, None, None, 5 0           add_1236[0][0]
#                                                                  leaky_re_lu_3868[0][0]
# __________________________________________________________________________________________________
# conv2d_4032 (Conv2D)            (None, None, None, 2 131072      add_1237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3869 (Batch (None, None, None, 2 1024        conv2d_4032[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3869 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3869[0][0]
# __________________________________________________________________________________________________
# conv2d_4033 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3869[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3870 (Batch (None, None, None, 5 2048        conv2d_4033[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3870 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3870[0][0]
# __________________________________________________________________________________________________
# add_1238 (Add)                  (None, None, None, 5 0           add_1237[0][0]
#                                                                  leaky_re_lu_3870[0][0]
# __________________________________________________________________________________________________
# conv2d_4034 (Conv2D)            (None, None, None, 2 131072      add_1238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3871 (Batch (None, None, None, 2 1024        conv2d_4034[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3871 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3871[0][0]
# __________________________________________________________________________________________________
# conv2d_4035 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3871[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3872 (Batch (None, None, None, 5 2048        conv2d_4035[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3872 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3872[0][0]
# __________________________________________________________________________________________________
# add_1239 (Add)                  (None, None, None, 5 0           add_1238[0][0]
#                                                                  leaky_re_lu_3872[0][0]
# __________________________________________________________________________________________________
# conv2d_4036 (Conv2D)            (None, None, None, 2 131072      add_1239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3873 (Batch (None, None, None, 2 1024        conv2d_4036[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3873 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3873[0][0]
# __________________________________________________________________________________________________
# conv2d_4037 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3873[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3874 (Batch (None, None, None, 5 2048        conv2d_4037[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3874 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3874[0][0]
# __________________________________________________________________________________________________
# add_1240 (Add)                  (None, None, None, 5 0           add_1239[0][0]
#                                                                  leaky_re_lu_3874[0][0]
# __________________________________________________________________________________________________
# conv2d_4038 (Conv2D)            (None, None, None, 2 131072      add_1240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3875 (Batch (None, None, None, 2 1024        conv2d_4038[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3875 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3875[0][0]
# __________________________________________________________________________________________________
# conv2d_4039 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3875[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3876 (Batch (None, None, None, 5 2048        conv2d_4039[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3876 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3876[0][0]
# __________________________________________________________________________________________________
# add_1241 (Add)                  (None, None, None, 5 0           add_1240[0][0]
#                                                                  leaky_re_lu_3876[0][0]
# __________________________________________________________________________________________________
# conv2d_4040 (Conv2D)            (None, None, None, 2 131072      add_1241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3877 (Batch (None, None, None, 2 1024        conv2d_4040[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3877 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3877[0][0]
# __________________________________________________________________________________________________
# conv2d_4041 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3877[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3878 (Batch (None, None, None, 5 2048        conv2d_4041[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3878 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3878[0][0]
# __________________________________________________________________________________________________
# add_1242 (Add)                  (None, None, None, 5 0           add_1241[0][0]
#                                                                  leaky_re_lu_3878[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_275 (ZeroPadding (None, None, None, 5 0           add_1242[0][0]
# __________________________________________________________________________________________________
# conv2d_4042 (Conv2D)            (None, None, None, 1 4718592     zero_padding2d_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3879 (Batch (None, None, None, 1 4096        conv2d_4042[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3879 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3879[0][0]
# __________________________________________________________________________________________________
# conv2d_4043 (Conv2D)            (None, None, None, 5 524288      leaky_re_lu_3879[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3880 (Batch (None, None, None, 5 2048        conv2d_4043[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3880 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3880[0][0]
# __________________________________________________________________________________________________
# conv2d_4044 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3880[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3881 (Batch (None, None, None, 1 4096        conv2d_4044[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3881 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3881[0][0]
# __________________________________________________________________________________________________
# add_1243 (Add)                  (None, None, None, 1 0           leaky_re_lu_3879[0][0]
#                                                                  leaky_re_lu_3881[0][0]
# __________________________________________________________________________________________________
# conv2d_4045 (Conv2D)            (None, None, None, 5 524288      add_1243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3882 (Batch (None, None, None, 5 2048        conv2d_4045[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3882 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3882[0][0]
# __________________________________________________________________________________________________
# conv2d_4046 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3882[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3883 (Batch (None, None, None, 1 4096        conv2d_4046[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3883 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3883[0][0]
# __________________________________________________________________________________________________
# add_1244 (Add)                  (None, None, None, 1 0           add_1243[0][0]
#                                                                  leaky_re_lu_3883[0][0]
# __________________________________________________________________________________________________
# conv2d_4047 (Conv2D)            (None, None, None, 5 524288      add_1244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3884 (Batch (None, None, None, 5 2048        conv2d_4047[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3884 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3884[0][0]
# __________________________________________________________________________________________________
# conv2d_4048 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3884[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3885 (Batch (None, None, None, 1 4096        conv2d_4048[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3885 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3885[0][0]
# __________________________________________________________________________________________________
# add_1245 (Add)                  (None, None, None, 1 0           add_1244[0][0]
#                                                                  leaky_re_lu_3885[0][0]
# __________________________________________________________________________________________________
# conv2d_4049 (Conv2D)            (None, None, None, 5 524288      add_1245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3886 (Batch (None, None, None, 5 2048        conv2d_4049[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3886 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3886[0][0]
# __________________________________________________________________________________________________
# conv2d_4050 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3886[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3887 (Batch (None, None, None, 1 4096        conv2d_4050[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3887 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3887[0][0]
# __________________________________________________________________________________________________
# add_1246 (Add)                  (None, None, None, 1 0           add_1245[0][0]
#                                                                  leaky_re_lu_3887[0][0]
# __________________________________________________________________________________________________
# conv2d_4051 (Conv2D)            (None, None, None, 5 524288      add_1246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3888 (Batch (None, None, None, 5 2048        conv2d_4051[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3888 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3888[0][0]
# __________________________________________________________________________________________________
# conv2d_4052 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3888[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3889 (Batch (None, None, None, 1 4096        conv2d_4052[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3889 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3889[0][0]
# __________________________________________________________________________________________________
# conv2d_4053 (Conv2D)            (None, None, None, 5 524288      leaky_re_lu_3889[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3890 (Batch (None, None, None, 5 2048        conv2d_4053[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3890 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3890[0][0]
# __________________________________________________________________________________________________
# conv2d_4054 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3890[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3891 (Batch (None, None, None, 1 4096        conv2d_4054[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3891 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3891[0][0]
# __________________________________________________________________________________________________
# conv2d_4055 (Conv2D)            (None, None, None, 5 524288      leaky_re_lu_3891[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3892 (Batch (None, None, None, 5 2048        conv2d_4055[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3892 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3892[0][0]
# __________________________________________________________________________________________________
# conv2d_4058 (Conv2D)            (None, None, None, 2 131072      leaky_re_lu_3892[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3894 (Batch (None, None, None, 2 1024        conv2d_4058[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3894 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3894[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_107 (UpSampling2D (None, None, None, 2 0           leaky_re_lu_3894[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, None, None, 7 0           up_sampling2d_107[0][0]
#                                                                  add_1242[0][0]
# __________________________________________________________________________________________________
# conv2d_4059 (Conv2D)            (None, None, None, 2 196608      concatenate_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3895 (Batch (None, None, None, 2 1024        conv2d_4059[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3895 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3895[0][0]
# __________________________________________________________________________________________________
# conv2d_4060 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3895[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3896 (Batch (None, None, None, 5 2048        conv2d_4060[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3896 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3896[0][0]
# __________________________________________________________________________________________________
# conv2d_4061 (Conv2D)            (None, None, None, 2 131072      leaky_re_lu_3896[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3897 (Batch (None, None, None, 2 1024        conv2d_4061[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3897 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3897[0][0]
# __________________________________________________________________________________________________
# conv2d_4062 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3897[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3898 (Batch (None, None, None, 5 2048        conv2d_4062[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3898 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3898[0][0]
# __________________________________________________________________________________________________
# conv2d_4063 (Conv2D)            (None, None, None, 2 131072      leaky_re_lu_3898[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3899 (Batch (None, None, None, 2 1024        conv2d_4063[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3899 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3899[0][0]
# __________________________________________________________________________________________________
# conv2d_4066 (Conv2D)            (None, None, None, 1 32768       leaky_re_lu_3899[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3901 (Batch (None, None, None, 1 512         conv2d_4066[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3901 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3901[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_108 (UpSampling2D (None, None, None, 1 0           leaky_re_lu_3901[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, None, None, 3 0           up_sampling2d_108[0][0]
#                                                                  add_1234[0][0]
# __________________________________________________________________________________________________
# conv2d_4067 (Conv2D)            (None, None, None, 1 49152       concatenate_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3902 (Batch (None, None, None, 1 512         conv2d_4067[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3902 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3902[0][0]
# __________________________________________________________________________________________________
# conv2d_4068 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3902[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3903 (Batch (None, None, None, 2 1024        conv2d_4068[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3903 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3903[0][0]
# __________________________________________________________________________________________________
# conv2d_4069 (Conv2D)            (None, None, None, 1 32768       leaky_re_lu_3903[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3904 (Batch (None, None, None, 1 512         conv2d_4069[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3904 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3904[0][0]
# __________________________________________________________________________________________________
# conv2d_4070 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3904[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3905 (Batch (None, None, None, 2 1024        conv2d_4070[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3905 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3905[0][0]
# __________________________________________________________________________________________________
# conv2d_4071 (Conv2D)            (None, None, None, 1 32768       leaky_re_lu_3905[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3906 (Batch (None, None, None, 1 512         conv2d_4071[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3906 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3906[0][0]
# __________________________________________________________________________________________________
# conv2d_4056 (Conv2D)            (None, None, None, 1 4718592     leaky_re_lu_3892[0][0]
# __________________________________________________________________________________________________
# conv2d_4064 (Conv2D)            (None, None, None, 5 1179648     leaky_re_lu_3899[0][0]
# __________________________________________________________________________________________________
# conv2d_4072 (Conv2D)            (None, None, None, 2 294912      leaky_re_lu_3906[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3893 (Batch (None, None, None, 1 4096        conv2d_4056[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3900 (Batch (None, None, None, 5 2048        conv2d_4064[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3907 (Batch (None, None, None, 2 1024        conv2d_4072[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3893 (LeakyReLU)    (None, None, None, 1 0           batch_normalization_3893[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3900 (LeakyReLU)    (None, None, None, 5 0           batch_normalization_3900[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3907 (LeakyReLU)    (None, None, None, 2 0           batch_normalization_3907[0][0]
# __________________________________________________________________________________________________
# conv2d_4057 (Conv2D)            (None, None, None, 3 36900       leaky_re_lu_3893[0][0]
# __________________________________________________________________________________________________
# conv2d_4065 (Conv2D)            (None, None, None, 3 18468       leaky_re_lu_3900[0][0]
# __________________________________________________________________________________________________
# conv2d_4073 (Conv2D)            (None, None, None, 3 9252        leaky_re_lu_3907[0][0]
# ==================================================================================================
# Total params: 61,608,652
# Trainable params: 61,556,044
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Saved Keras model to yolov3.h5
# Read 61608652 of 62001757.0 from Darknet weights.
# Warning: 393105.0 unused weights

# %% [markdown]
# ## 물체 탐지 실행
#
# 다음의 파일이 필요하다.
# - yolov3.h5 : 모델 파일
# - model_data/coco_classes.txt : 클래스 이름

# %% [markdown]
# # 커스텀 데이터 적용

# %% [markdown]
# ## 커스텀 데이터 업로드

# %%
'''
#파일 수정해서 올릴때 필요한 코드

# %cd /content/keras-yolo3/resize_data
#! rm *

# %cd /content/keras-yolo3

#! rm resize_data.zip
#! rm -r resize_data/
'''
# Out:
# '\n#파일 수정해서 올릴때 필요한 코드\n\n%cd /content/keras-yolo3/resize_data\n#! rm *\n\n%cd /content/keras-yolo3\n\n#! rm resize_data.zip\n#! rm -r resize_data/\n'

# %%
# 파일이름 resize_data.zip

# %cd /content/keras-yolo3

! pip install gdown
! gdown https://drive.google.com/uc?id=1WLx_VMJkMoWdwv5vk8njN4a086HMQl90

# P1 x 40 파일, 파일이름 resize_data.zip 으로 수정 : 2020 11 02 
#https://drive.google.com/file/d/1G8fP26ddYYYQ7qwv0xmEWXdoRLsHWmL8/view?usp=sharing
#https://drive.google.com/file/d/19xArUWBBavTfgpWKZc7m83PfQgGJNLqE/view?usp=sharing

#! mv P1x40_1103.zip resize_data.zip
# Out:
# [Errno 2] No such file or directory: '/content/keras-yolo3'
# /home/ubuntu/cell
# Collecting gdown
#   Downloading gdown-3.13.0.tar.gz (9.3 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: six in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from gdown) (1.16.0)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting tqdm
#   Downloading tqdm-4.61.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 673 kB/s eta 0:00:01
# Requirement already satisfied: requests[socks]>=2.12.0 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from gdown) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/ubuntu/anaconda3/envs/cell/lib/python3.7/site-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.13.0-py3-none-any.whl size=9034 sha256=0b38f6cd3c30f3bea84322dbf671163851a2aba4bb735f8985e60a7a81258628
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/2f/2a/2f/86449b6bdbaa9aef873f68332b68be6bfbc386b9219f47157d
# Successfully built gdown
# Installing collected packages: tqdm, filelock, gdown
# Successfully installed filelock-3.0.12 gdown-3.13.0 tqdm-4.61.2
# Downloading...
# From: https://drive.google.com/uc?id=1WLx_VMJkMoWdwv5vk8njN4a086HMQl90
# To: /home/ubuntu/cell/resize_data.zip
# 676MB [01:00, 11.2MB/s]

# %%
#zip 압축 파일 풀기 # 파일이름 resize_data.zip

# !mkdir data

# !unzip data.zip -d ./data
# Out:
# Archive:  resize_data.zip
#   inflating: ./resize_data/Annotations/P1-0001.xml
#   inflating: ./resize_data/Annotations/P1-0002.xml
#   inflating: ./resize_data/Annotations/P1-0004.xml
#   inflating: ./resize_data/Annotations/P1-0005.xml
#   inflating: ./resize_data/Annotations/P1-0006.xml
#   inflating: ./resize_data/Annotations/P1-0007.xml
#   inflating: ./resize_data/Annotations/P1-0008.xml
#   inflating: ./resize_data/Annotations/P1-0009.xml
#   inflating: ./resize_data/Annotations/P1-0010.xml
#   inflating: ./resize_data/Annotations/P1-0011.xml
#   inflating: ./resize_data/Annotations/P1-0012.xml
#   inflating: ./resize_data/Annotations/P1-0013.xml
#   inflating: ./resize_data/Annotations/P1-0014.xml
#   inflating: ./resize_data/Annotations/P1-0015.xml
#   inflating: ./resize_data/Annotations/P1-0016.xml
#   inflating: ./resize_data/Annotations/P1-0017.xml
#   inflating: ./resize_data/Annotations/P1-0018.xml
#   inflating: ./resize_data/Annotations/P1-0019.xml
#   inflating: ./resize_data/Annotations/P1-0020.xml
#   inflating: ./resize_data/Annotations/P1-0021.xml
#   inflating: ./resize_data/Annotations/P1-0022.xml
#   inflating: ./resize_data/Annotations/P1-0023.xml
#   inflating: ./resize_data/Annotations/P1-0024.xml
#   inflating: ./resize_data/Annotations/P1-0025.xml
#   inflating: ./resize_data/Annotations/P1-0026.xml
#   inflating: ./resize_data/Annotations/P1-0027.xml
#   inflating: ./resize_data/Annotations/P1-0028.xml
#   inflating: ./resize_data/Annotations/P1-0029.xml
#   inflating: ./resize_data/Annotations/P1-0088.xml
#   inflating: ./resize_data/Annotations/P1-0089.xml
#   inflating: ./resize_data/Annotations/P1-0090.xml
#   inflating: ./resize_data/Annotations/P1-0091.xml
#   inflating: ./resize_data/Annotations/P1-0092.xml
#   inflating: ./resize_data/Annotations/P1-0093.xml
#   inflating: ./resize_data/Annotations/P1-0094.xml
#   inflating: ./resize_data/Annotations/P1-0095.xml
#   inflating: ./resize_data/Annotations/P1-0096.xml
#   inflating: ./resize_data/Annotations/P1-0097.xml
#   inflating: ./resize_data/Annotations/P1-0099.xml
#   inflating: ./resize_data/Annotations/P1-0100.xml
#   inflating: ./resize_data/Annotations/P1-0101.xml
#   inflating: ./resize_data/Annotations/P1-0102.xml
#   inflating: ./resize_data/Annotations/P1-0103.xml
#   inflating: ./resize_data/Annotations/P1-0104.xml
#   inflating: ./resize_data/Annotations/P1-0105.xml
#   inflating: ./resize_data/Annotations/P1-0106.xml
#   inflating: ./resize_data/Annotations/P1-0107.xml
#   inflating: ./resize_data/Annotations/P1-0109.xml
#   inflating: ./resize_data/Annotations/P1-0110.xml
#   inflating: ./resize_data/Annotations/P1-0111.xml
#   inflating: ./resize_data/Annotations/P1-0112.xml
#   inflating: ./resize_data/Annotations/P1-0113.xml
#   inflating: ./resize_data/Annotations/P1-0115.xml
#   inflating: ./resize_data/Annotations/p5-0020.xml
#   inflating: ./resize_data/Annotations/p5-0021.xml
#   inflating: ./resize_data/Annotations/p5-0022.xml
#   inflating: ./resize_data/Annotations/p5-0023.xml
#   inflating: ./resize_data/Annotations/p5-0024.xml
#   inflating: ./resize_data/Annotations/p5-0025.xml
#   inflating: ./resize_data/Annotations/p5-0026.xml
#   inflating: ./resize_data/Annotations/p5-0027.xml
#   inflating: ./resize_data/Annotations/p5-0028.xml
#   inflating: ./resize_data/Annotations/p5-0029.xml
#   inflating: ./resize_data/Annotations/p5-0030.xml
#   inflating: ./resize_data/Annotations/p5-0031.xml
#   inflating: ./resize_data/Annotations/p5-0032.xml
#   inflating: ./resize_data/Annotations/p5-0033.xml
#   inflating: ./resize_data/Annotations/p5-0034.xml
#   inflating: ./resize_data/Annotations/p5-0035.xml
#   inflating: ./resize_data/Annotations/p5-0036.xml
#   inflating: ./resize_data/Annotations/p5-0037.xml
#   inflating: ./resize_data/Annotations/p5-0038.xml
#   inflating: ./resize_data/Annotations/p5-0039.xml
#   inflating: ./resize_data/Annotations/p5-0040.xml
#   inflating: ./resize_data/Annotations/p5-0041.xml
#   inflating: ./resize_data/Annotations/p5-0042.xml
#   inflating: ./resize_data/Annotations/p5-0054.xml
#   inflating: ./resize_data/Annotations/p5-0055.xml
#   inflating: ./resize_data/Annotations/p5-0056.xml
#   inflating: ./resize_data/Annotations/p5-0057.xml
#   inflating: ./resize_data/Annotations/p5-0058.xml
#   inflating: ./resize_data/Annotations/p5-0059.xml
#   inflating: ./resize_data/Annotations/p5-0060.xml
#   inflating: ./resize_data/Annotations/p5-0061.xml
#   inflating: ./resize_data/Annotations/p5-0062.xml
#   inflating: ./resize_data/Annotations/p5-0063.xml
#   inflating: ./resize_data/Annotations/p5-0064.xml
#   inflating: ./resize_data/Annotations/p5-0065.xml
#   inflating: ./resize_data/Annotations/p5-0066.xml
#   inflating: ./resize_data/Annotations/p5-0067.xml
#   inflating: ./resize_data/Annotations/p5-0068.xml
#   inflating: ./resize_data/Annotations/p5-0069.xml
#   inflating: ./resize_data/Annotations/p5-0070.xml
#   inflating: ./resize_data/Annotations/p5-0071.xml
#   inflating: ./resize_data/Annotations/p5-0072.xml
#   inflating: ./resize_data/Annotations/p5-0073.xml
#   inflating: ./resize_data/Annotations/p5-0074.xml
#   inflating: ./resize_data/Annotations/p5-0075.xml
#   inflating: ./resize_data/Annotations/p5-0076.xml
#   inflating: ./resize_data/Annotations/p5-0077.xml
#   inflating: ./resize_data/Annotations/p5-0078.xml
#   inflating: ./resize_data/Annotations/p5-0079.xml
#   inflating: ./resize_data/Annotations/p5-0080.xml
#   inflating: ./resize_data/Annotations/p5-0081.xml
#   inflating: ./resize_data/Annotations/p5-0082.xml
#   inflating: ./resize_data/Annotations/p5-0083.xml
#   inflating: ./resize_data/Annotations/p5-0084.xml
#   inflating: ./resize_data/Annotations/p5-0085.xml
#   inflating: ./resize_data/Annotations/p5-0086.xml
#   inflating: ./resize_data/Annotations/p5-0087.xml
#   inflating: ./resize_data/Annotations/p6-0001.xml
#   inflating: ./resize_data/Annotations/p6-0002.xml
#   inflating: ./resize_data/Annotations/p6-0003.xml
#   inflating: ./resize_data/Annotations/p6-0004.xml
#   inflating: ./resize_data/Annotations/p6-0005.xml
#   inflating: ./resize_data/Annotations/p6-0006.xml
#   inflating: ./resize_data/Annotations/p6-0007.xml
#   inflating: ./resize_data/Annotations/p6-0008.xml
#   inflating: ./resize_data/Annotations/p6-0009.xml
#   inflating: ./resize_data/Annotations/p6-0010.xml
#   inflating: ./resize_data/Annotations/p6-0011.xml
#   inflating: ./resize_data/Annotations/p6-0012.xml
#   inflating: ./resize_data/Annotations/p6-0013.xml
#   inflating: ./resize_data/Annotations/p6-0014.xml
#   inflating: ./resize_data/Annotations/p6-0015.xml
#   inflating: ./resize_data/Annotations/p6-0016.xml
#   inflating: ./resize_data/Annotations/p6-0017.xml
#   inflating: ./resize_data/Annotations/p6-0018.xml
#   inflating: ./resize_data/Annotations/p6-0019.xml
#   inflating: ./resize_data/Annotations/p6-0020.xml
#   inflating: ./resize_data/Annotations/p6-0021.xml
#   inflating: ./resize_data/Annotations/p6-0022.xml
#   inflating: ./resize_data/Annotations/p6-0023.xml
#   inflating: ./resize_data/Annotations/p6-0024.xml
#   inflating: ./resize_data/Annotations/p6-0025.xml
#   inflating: ./resize_data/Annotations/p6-0027.xml
#   inflating: ./resize_data/Annotations/p6-0028.xml
#   inflating: ./resize_data/Annotations/p6-0029.xml
#   inflating: ./resize_data/Annotations/p6-0030.xml
#   inflating: ./resize_data/Annotations/p6-0031.xml
#   inflating: ./resize_data/Annotations/p6-0032.xml
#   inflating: ./resize_data/Annotations/p6-0033.xml
#   inflating: ./resize_data/Annotations/p6-0034.xml
#   inflating: ./resize_data/Annotations/p6-0035.xml
#   inflating: ./resize_data/Annotations/p6-0036.xml
#   inflating: ./resize_data/Annotations/p6-0037.xml
#   inflating: ./resize_data/Annotations/p6-0038.xml
#   inflating: ./resize_data/Annotations/p6-0039.xml
#   inflating: ./resize_data/Annotations/p6-0040.xml
#   inflating: ./resize_data/Annotations/p6-0041.xml
#   inflating: ./resize_data/Annotations/p6-0042.xml
#   inflating: ./resize_data/Annotations/p6-0043.xml
#   inflating: ./resize_data/Annotations/p6-0044.xml
#   inflating: ./resize_data/Annotations/p6-0045.xml
#   inflating: ./resize_data/Annotations/p6-0046.xml
#   inflating: ./resize_data/Annotations/p6-0047.xml
#   inflating: ./resize_data/Annotations/p6-0048.xml
#   inflating: ./resize_data/Annotations/p6-0056.xml
#   inflating: ./resize_data/Annotations/p6-0057.xml
#   inflating: ./resize_data/Annotations/p6-0058.xml
#   inflating: ./resize_data/Annotations/p6-0059.xml
#   inflating: ./resize_data/Annotations/p6-0060.xml
#   inflating: ./resize_data/Annotations/p6-0061.xml
#   inflating: ./resize_data/Annotations/p6-0062.xml
#   inflating: ./resize_data/Annotations/p6-0063.xml
#   inflating: ./resize_data/Annotations/p6-0064.xml
#   inflating: ./resize_data/Annotations/p6-0065.xml
#   inflating: ./resize_data/Annotations/p6-0066.xml
#   inflating: ./resize_data/Annotations/p6-0067.xml
#   inflating: ./resize_data/Annotations/p6-0068.xml
#   inflating: ./resize_data/Annotations/p6-0069.xml
#   inflating: ./resize_data/Annotations/p6-0070.xml
#   inflating: ./resize_data/Annotations/p6-0071.xml
#   inflating: ./resize_data/Annotations/p6-0072.xml
#   inflating: ./resize_data/Annotations/p6-0073.xml
#   inflating: ./resize_data/Annotations/p6-0074.xml
#   inflating: ./resize_data/Annotations/p6-0075.xml
#   inflating: ./resize_data/Annotations/p6-0076.xml
#   inflating: ./resize_data/Annotations/p6-0077.xml
#   inflating: ./resize_data/Annotations/p6-0078.xml
#   inflating: ./resize_data/Annotations/p6-0079.xml
#   inflating: ./resize_data/Annotations/p6-0080.xml
#   inflating: ./resize_data/Annotations/p6-0081.xml
#   inflating: ./resize_data/Annotations/p6-0082.xml
#   inflating: ./resize_data/Annotations/p6-0083.xml
#   inflating: ./resize_data/Annotations/p7-0001.xml
#   inflating: ./resize_data/Annotations/p7-0002.xml
#   inflating: ./resize_data/Annotations/p7-0003.xml
#   inflating: ./resize_data/Annotations/p7-0004.xml
#   inflating: ./resize_data/Annotations/p7-0005.xml
#   inflating: ./resize_data/Annotations/p7-0006.xml
#   inflating: ./resize_data/Annotations/p7-0007.xml
#   inflating: ./resize_data/Annotations/p7-0008.xml
#   inflating: ./resize_data/Annotations/p7-0009.xml
#   inflating: ./resize_data/Annotations/p7-0010.xml
#   inflating: ./resize_data/Annotations/p7-0011.xml
#   inflating: ./resize_data/Annotations/p7-0012.xml
#   inflating: ./resize_data/Annotations/p7-0013.xml
#   inflating: ./resize_data/Annotations/p7-0014.xml
#   inflating: ./resize_data/Annotations/p7-0015.xml
#   inflating: ./resize_data/Annotations/p7-0016.xml
#   inflating: ./resize_data/Annotations/p7-0017.xml
#   inflating: ./resize_data/Annotations/p7-0018.xml
#   inflating: ./resize_data/Annotations/p7-0019.xml
#   inflating: ./resize_data/Annotations/p7-0020.xml
#   inflating: ./resize_data/Annotations/p7-0021.xml
#   inflating: ./resize_data/Annotations/p7-0022.xml
#   inflating: ./resize_data/Annotations/p7-0023.xml
#   inflating: ./resize_data/Annotations/p7-0024.xml
#   inflating: ./resize_data/Annotations/p7-0025.xml
#   inflating: ./resize_data/Annotations/p7-0026.xml
#   inflating: ./resize_data/Annotations/p7-0027.xml
#   inflating: ./resize_data/Annotations/p7-0028.xml
#   inflating: ./resize_data/Annotations/p7-0029.xml
#   inflating: ./resize_data/Annotations/p7-0030.xml
#   inflating: ./resize_data/Annotations/p7-0031.xml
#   inflating: ./resize_data/Annotations/p7-0032.xml
#   inflating: ./resize_data/Annotations/p7-0033.xml
#   inflating: ./resize_data/Annotations/p7-0034.xml
#   inflating: ./resize_data/Annotations/p7-0035.xml
#   inflating: ./resize_data/Annotations/p7-0036.xml
#   inflating: ./resize_data/Annotations/p7-0037.xml
#   inflating: ./resize_data/Annotations/p7-0038.xml
#   inflating: ./resize_data/Annotations/p7-0039.xml
#   inflating: ./resize_data/Annotations/p7-0040.xml
#   inflating: ./resize_data/Annotations/p7-0041.xml
#   inflating: ./resize_data/Annotations/p7-0042.xml
#   inflating: ./resize_data/Annotations/p7-0043.xml
#   inflating: ./resize_data/Annotations/p7-0044.xml
#   inflating: ./resize_data/Annotations/p7-0045.xml
#   inflating: ./resize_data/Annotations/p7-0046.xml
#   inflating: ./resize_data/Annotations/p7-0047.xml
#   inflating: ./resize_data/Annotations/p7-0048.xml
#   inflating: ./resize_data/Annotations/p7-0049.xml
#   inflating: ./resize_data/Annotations/p7-0050.xml
#   inflating: ./resize_data/Annotations/p7-0051.xml
#   inflating: ./resize_data/Annotations/p7-0052.xml
#   inflating: ./resize_data/Annotations/p7-0053.xml
#   inflating: ./resize_data/Annotations/p7-0054.xml
#   inflating: ./resize_data/Annotations/p7-0055.xml
#   inflating: ./resize_data/Annotations/p7-0056.xml
#   inflating: ./resize_data/Annotations/p7-0057.xml
#   inflating: ./resize_data/Annotations/p7-0058.xml
#   inflating: ./resize_data/Annotations/p7-0059.xml
#   inflating: ./resize_data/Annotations/p7-0060.xml
#   inflating: ./resize_data/Annotations/p7-0061.xml
#   inflating: ./resize_data/Annotations/p7-0062.xml
#   inflating: ./resize_data/Annotations/p7-0063.xml
#   inflating: ./resize_data/Annotations/p7-0064.xml
#   inflating: ./resize_data/Annotations/p7-0065.xml
#   inflating: ./resize_data/Annotations/p7-0066.xml
#   inflating: ./resize_data/Annotations/p7-0067.xml
#   inflating: ./resize_data/Annotations/p7-0068.xml
#   inflating: ./resize_data/Annotations/p7-0069.xml
#   inflating: ./resize_data/Annotations/p7-0070.xml
#   inflating: ./resize_data/Annotations/p7-0071.xml
#   inflating: ./resize_data/Annotations/p7-0072.xml
#   inflating: ./resize_data/Annotations/p7-0073.xml
#   inflating: ./resize_data/Annotations/p7-0074.xml
#   inflating: ./resize_data/Annotations/p7-0076.xml
#   inflating: ./resize_data/Annotations/p7-0077.xml
#   inflating: ./resize_data/Annotations/p7-0078.xml
#   inflating: ./resize_data/Annotations/p7-0079.xml
#   inflating: ./resize_data/Annotations/p7-0080.xml
#   inflating: ./resize_data/Annotations/p7-0081.xml
#   inflating: ./resize_data/Annotations/p7-0082.xml
#   inflating: ./resize_data/Annotations/p7-0083.xml
#   inflating: ./resize_data/Annotations/p7-0084.xml
#  extracting: ./resize_data/JPEGImages/P1-0001.jpg
#  extracting: ./resize_data/JPEGImages/P1-0002.jpg
#  extracting: ./resize_data/JPEGImages/P1-0004.jpg
#  extracting: ./resize_data/JPEGImages/P1-0005.jpg
#  extracting: ./resize_data/JPEGImages/P1-0006.jpg
#  extracting: ./resize_data/JPEGImages/P1-0007.jpg
#  extracting: ./resize_data/JPEGImages/P1-0008.jpg
#  extracting: ./resize_data/JPEGImages/P1-0009.jpg
#  extracting: ./resize_data/JPEGImages/P1-0010.jpg
#  extracting: ./resize_data/JPEGImages/P1-0011.jpg
#  extracting: ./resize_data/JPEGImages/P1-0012.jpg
#  extracting: ./resize_data/JPEGImages/P1-0013.jpg
#  extracting: ./resize_data/JPEGImages/P1-0014.jpg
#  extracting: ./resize_data/JPEGImages/P1-0015.jpg
#  extracting: ./resize_data/JPEGImages/P1-0016.jpg
#  extracting: ./resize_data/JPEGImages/P1-0017.jpg
#  extracting: ./resize_data/JPEGImages/P1-0018.jpg
#  extracting: ./resize_data/JPEGImages/P1-0019.jpg
#  extracting: ./resize_data/JPEGImages/P1-0020.jpg
#  extracting: ./resize_data/JPEGImages/P1-0021.jpg
#  extracting: ./resize_data/JPEGImages/P1-0022.jpg
#  extracting: ./resize_data/JPEGImages/P1-0023.jpg
#  extracting: ./resize_data/JPEGImages/P1-0024.jpg
#  extracting: ./resize_data/JPEGImages/P1-0025.jpg
#  extracting: ./resize_data/JPEGImages/P1-0026.jpg
#  extracting: ./resize_data/JPEGImages/P1-0027.jpg
#  extracting: ./resize_data/JPEGImages/P1-0028.jpg
#  extracting: ./resize_data/JPEGImages/P1-0029.jpg
#  extracting: ./resize_data/JPEGImages/P1-0088.jpg
#  extracting: ./resize_data/JPEGImages/P1-0089.jpg
#  extracting: ./resize_data/JPEGImages/P1-0090.jpg
#  extracting: ./resize_data/JPEGImages/P1-0091.jpg
#  extracting: ./resize_data/JPEGImages/P1-0092.jpg
#  extracting: ./resize_data/JPEGImages/P1-0093.jpg
#  extracting: ./resize_data/JPEGImages/P1-0094.jpg
#  extracting: ./resize_data/JPEGImages/P1-0095.jpg
#  extracting: ./resize_data/JPEGImages/P1-0096.jpg
#  extracting: ./resize_data/JPEGImages/P1-0097.jpg
#  extracting: ./resize_data/JPEGImages/P1-0099.jpg
#  extracting: ./resize_data/JPEGImages/P1-0100.jpg
#  extracting: ./resize_data/JPEGImages/P1-0101.jpg
#  extracting: ./resize_data/JPEGImages/P1-0102.jpg
#  extracting: ./resize_data/JPEGImages/P1-0103.jpg
#  extracting: ./resize_data/JPEGImages/P1-0104.jpg
#  extracting: ./resize_data/JPEGImages/P1-0105.jpg
#  extracting: ./resize_data/JPEGImages/P1-0106.jpg
#  extracting: ./resize_data/JPEGImages/P1-0107.jpg
#  extracting: ./resize_data/JPEGImages/P1-0109.jpg
#  extracting: ./resize_data/JPEGImages/P1-0110.jpg
#  extracting: ./resize_data/JPEGImages/P1-0111.jpg
#  extracting: ./resize_data/JPEGImages/P1-0112.jpg
#  extracting: ./resize_data/JPEGImages/P1-0113.jpg
#  extracting: ./resize_data/JPEGImages/P1-0115.jpg
#  extracting: ./resize_data/JPEGImages/P1-0116.jpg
#  extracting: ./resize_data/JPEGImages/P1-0117.jpg
#  extracting: ./resize_data/JPEGImages/P1-0118.jpg
#  extracting: ./resize_data/JPEGImages/P1-0119.jpg
#  extracting: ./resize_data/JPEGImages/P1-0120.jpg
#  extracting: ./resize_data/JPEGImages/P1-0121.jpg
#  extracting: ./resize_data/JPEGImages/P1-0122.jpg
#  extracting: ./resize_data/JPEGImages/P1-0123.jpg
#  extracting: ./resize_data/JPEGImages/P1-0124.jpg
#  extracting: ./resize_data/JPEGImages/p7-0054.jpg
#  extracting: ./resize_data/JPEGImages/p7-0055.jpg
#  extracting: ./resize_data/JPEGImages/p7-0056.jpg
#  extracting: ./resize_data/JPEGImages/p7-0057.jpg
#  extracting: ./resize_data/JPEGImages/p7-0058.jpg
#  extracting: ./resize_data/JPEGImages/p7-0059.jpg
#  extracting: ./resize_data/JPEGImages/p7-0060.jpg
#  extracting: ./resize_data/JPEGImages/p7-0061.jpg
#  extracting: ./resize_data/JPEGImages/p7-0062.jpg
#  extracting: ./resize_data/JPEGImages/p7-0063.jpg
#  extracting: ./resize_data/JPEGImages/p7-0064.jpg
#  extracting: ./resize_data/JPEGImages/p7-0065.jpg
#  extracting: ./resize_data/JPEGImages/p7-0066.jpg
#  extracting: ./resize_data/JPEGImages/p7-0067.jpg
#  extracting: ./resize_data/JPEGImages/p7-0068.jpg
#  extracting: ./resize_data/JPEGImages/p7-0069.jpg
#  extracting: ./resize_data/JPEGImages/p7-0070.jpg
#  extracting: ./resize_data/JPEGImages/p7-0071.jpg
#  extracting: ./resize_data/JPEGImages/p7-0072.jpg
#  extracting: ./resize_data/JPEGImages/p7-0073.jpg
#  extracting: ./resize_data/JPEGImages/p7-0074.jpg
#  extracting: ./resize_data/JPEGImages/p7-0076.jpg
#  extracting: ./resize_data/JPEGImages/p7-0077.jpg
#  extracting: ./resize_data/JPEGImages/p7-0078.jpg
#  extracting: ./resize_data/JPEGImages/p7-0079.jpg
#  extracting: ./resize_data/JPEGImages/p7-0080.jpg
#  extracting: ./resize_data/JPEGImages/p7-0081.jpg
#  extracting: ./resize_data/JPEGImages/p7-0082.jpg
#  extracting: ./resize_data/JPEGImages/p7-0083.jpg
#  extracting: ./resize_data/JPEGImages/p7-0084.jpg
#  extracting: ./resize_data/classes.txt

# %%
# 압출 풀린 파일들 확인
# !ls -al resize_data
# Out:
# 합계 52
# drwxrwxr-x 4 ubuntu ubuntu  4096  7월 29 10:55 .
# drwxrwxr-x 6 ubuntu ubuntu  4096  7월 29 10:55 ..
# drwxrwxr-x 2 ubuntu ubuntu 20480  7월 29 10:55 Annotations
# drwxrwxr-x 2 ubuntu ubuntu 20480  7월 29 10:55 JPEGImages
# -rw-rw-r-- 1 ubuntu ubuntu    44  7월  8 18:42 classes.txt

# %% [markdown]
# ## VOC 포멧의 레이블링 데이터를  darknet 포멧으로 변경

# %%
# copy and modified from voc_annotation.py

import xml.etree.ElementTree as ET
from os import getcwd
import glob


def convert_voc_2_darknet(data_folder_name, converted_file_name):
  
  def load_classes():
      with open('%s/classes.txt'%(data_folder_name)) as f:
          classes = f.read().splitlines()

      return classes

  def convert_annotation(image_id, converted_file):
      tree=ET.parse('%s/Annotations/%s.xml'%(data_folder_name, image_id))
      root = tree.getroot()

      for obj in root.iter('object'):
          difficult = obj.find('difficult').text
          cls = obj.find('name').text
          if cls not in classes or int(difficult)==1:
              continue
          cls_id = classes.index(cls)
          xmlbox = obj.find('bndbox')
          b = (int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text))
          converted_file.write(" " + ",".join([str(a) for a in b]) + ',' + str(cls_id))

  # classes = ['tooth', 'decayed', 'cured']
  classes = load_classes()


  # image_ids = ['101', '102', ... '305']
  image_ids = [ f.replace(".xml", "").replace("%s/Annotations/"%(data_folder_name), "") for f in glob.glob('%s/Annotations/*.xml'%(DATA_FOLDER_NAME))]


  wd = getcwd()


  converted_file = open(converted_file_name, 'w')
  for image_id in image_ids:
      converted_file.write('%s/JPEGImages/%s.jpg'%(data_folder_name, image_id))
      convert_annotation(image_id, converted_file)
      converted_file.write('\n')
  converted_file.close()


DATA_FOLDER_NAME = "/home/ubuntu/cell/keras-yolo3/crop_to_4"
CONVERTED_FILE_NAME = "train_all.txt"

convert_voc_2_darknet(DATA_FOLDER_NAME, CONVERTED_FILE_NAME)

# %%
# !ls -al train_all.txt
# !head -10 train_all.txt
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 1281002 10월 20 13:09 train_all.txt
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/03_P2--0082.jpg 214,311,341,417,3 104,352,249,446,3 106,76,290,190,3 430,130,608,360,3 315,187,395,277,1 145,170,296,282,3 39,359,118,429,1 30,339,57,411,1 387,52,431,212,1 353,355,503,480,3 532,388,584,480,1
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/04_P2--0072.jpg
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/01_P3--0063.jpg 37,130,109,195,1 45,271,113,357,3 34,232,94,288,1 104,115,237,265,3 146,53,229,95,1 117,30,181,59,1 69,3,176,27,1 360,18,431,74,1 253,313,281,362,1 223,382,271,416,1 83,395,161,466,1 373,388,513,469,1 330,313,399,370,1 384,196,434,245,1 405,240,456,288,1 468,235,494,270,1 482,208,513,272,1 478,175,509,233,1 423,111,509,133,1 407,73,513,109,1 582,88,620,153,1 561,48,618,85,0 488,296,553,341,1 456,343,495,390,1 404,300,499,370,1 409,370,468,397,1 543,373,571,431,1 575,399,613,465,1 522,324,626,394,1
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/03_p5-0064.jpg 213,10,290,90,1 190,144,239,210,1 246,154,293,189,1 270,111,316,190,1 355,5,477,197,3 332,178,401,237,5 394,208,430,266,5 239,295,362,444,3 114,355,164,399,5 67,382,134,432,3 374,328,493,448,3 547,120,601,206,1 485,108,564,154,1 449,17,549,94,1 554,291,640,418,3 119,212,150,295,1 127,208,181,280,1 101,157,167,246,1 72,155,108,203,1 22,174,121,236,1 94,49,172,151,3 145,32,197,86,1
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/02_P1-0027.jpg 223,73,241,89,4 222,91,238,103,4 62,167,82,191,4 564,110,628,126,1 407,92,420,107,4 35,57,68,110,1 1,80,46,144,1 359,73,435,168,3 181,69,204,115,1 175,3,222,79,1 563,264,617,308,1 504,348,557,378,1 434,178,452,199,4 393,246,425,295,1 322,70,356,180,1 122,232,162,284,1 2,152,57,206,1 235,342,272,365,1 216,325,244,360,1 226,277,286,339,3 209,378,247,399,1 255,390,283,423,1 217,359,278,392,1 212,153,286,190,3 0,56,52,79,1 405,208,429,255,1 248,120,266,154,1 340,386,375,460,1 330,413,339,420,0 549,66,575,111,1 199,111,244,157,1 242,86,275,119,1
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/02_P2--0028.jpg 587,322,631,352,1 338,131,352,147,4 325,128,339,145,4 426,148,477,183,1 483,169,554,197,1 519,85,554,161,1 343,23,404,77,1 88,50,121,113,1 123,35,151,90,1 130,107,163,168,1 34,128,70,189,1 144,49,254,164,3 101,170,125,208,1 55,273,157,343,1 87,342,129,367,1 46,371,108,411,1 386,251,426,357,1 472,228,496,254,4 229,240,273,324,1 197,31,212,46,4 464,46,485,67,0 500,281,553,360,1 467,405,491,463,1 147,188,173,216,0 507,81,531,106,1 493,79,510,129,1 552,286,576,375,1 569,345,584,379,1 568,429,579,448,0 527,416,544,463,1 90,167,185,267,3 222,293,307,383,3
# /home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/04_P2--0067.jpg 44,12,135,65,1 88,56,158,118,0 10,184,52,231,1 114,194,160,262,1 28,301,81,374,1 24,423,103,447,1 50,346,159,389,1 132,318,172,378,1 231,271,263,296,0 244,286,275,319,0 203,292,246,324,0 224,331,279,367,0 187,320,239,350,0 385,244,426,267,5 172,150,193,173,0 270,136,296,184,1 366,162,402,189,0 340,170,368,195,0 270,33,355,158,3 333,21,398,85,1 329,1,366,76,1 429,225,445,283,1 422,191,448,234,1 446,81,514,121,1 552,42,587,165,1 553,177,598,236,1 561,251,633,321,1 520,274,555,321,0 490,279,525,344,1 473,418,539,468,1 540,330,636,462,3 450,369,474,405,0 416,319,447,406,1 437,325,464,397,1 544,1,609,37,1

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
'''
1280	40.00	3.076923077
960	30.00	2.307692308
'''
# Out:
# '\n1280\t40.00\t3.076923077\n960\t30.00\t2.307692308\n'

# %%
# copy and modified from train.py

"""
Retrain the YOLO model for your own dataset.
"""

import numpy as np
import keras.backend as K
from keras.layers import Input, Lambda
from keras.models import Model
from keras.optimizers import Adam
#from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

from yolo3.model import preprocess_true_boxes, yolo_body, tiny_yolo_body, yolo_loss
from yolo3.utils import get_random_data


def _main():
#    annotation_path = 'train.txt'
    annotation_path = '/home/ubuntu/cell/keras-yolo3/train_all.txt' # Modified
    log_dir = '/home/ubuntu/cell/keras-yolo3/crop_to_4/logs/000/'
#    classes_path = 'model_data/voc_classes.txt' # Modified    
    classes_path = '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt'
    anchors_path = '/home/ubuntu/cell/keras-yolo3/model_data/yolo_anchors.txt'
    class_names = get_classes(classes_path)
    num_classes = len(class_names)
    anchors = get_anchors(anchors_path)

#------------------------------------------------------------------------------------- 이미지 사이즈를 수정함 2020 10 12
    #input_shape = (416, 416) # multiple of 32, hw
    input_shape = (640, 480) # multiple of 32, hw

    is_tiny_version = len(anchors)==6 # default setting
    if is_tiny_version:
        model = create_tiny_model(input_shape, anchors, num_classes,
#            freeze_body=2, weights_path='model_data/tiny_yolo_weights.h5')
            freeze_body=2, weights_path='/home/ubuntu/cell/keras-yolo3/yolov3_tiny.h5') # Modified
    else:
        model = create_model(input_shape, anchors, num_classes,
#            freeze_body=2, weights_path='model_data/yolo_weights.h5')
            freeze_body=2, weights_path='/home/ubuntu/cell/keras-yolo3/yolov3.h5') # Modified

    logging = TensorBoard(log_dir=log_dir)
    checkpoint = ModelCheckpoint(log_dir + 'ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5',
        monitor='val_loss', save_weights_only=True, save_best_only=True, period=3)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

    val_split = 0.1
    with open(annotation_path) as f:
        lines = f.readlines()
    np.random.seed(10101)
    np.random.shuffle(lines)
    np.random.seed(None)
    num_val = int(len(lines)*val_split)
    num_train = len(lines) - num_val

    # Train with frozen layers first, to get a stable loss.
    # Adjust num epochs to your dataset. This step is enough to obtain a not bad model.
    if True:
        model.compile(optimizer=Adam(lr=1e-3), loss={
            # use custom yolo_loss Lambda layer.
            'yolo_loss': lambda y_true, y_pred: y_pred})

        # batch_size = 32, 16
        batch_size = 16
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
                steps_per_epoch=max(1, num_train//batch_size),
                validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
                validation_steps=max(1, num_val//batch_size),
                epochs=50,
                initial_epoch=0,
                callbacks=[logging, checkpoint])
        model.save_weights(log_dir + 'trained_weights_stage_1.h5')

    # Unfreeze and continue training, to fine-tune.
    # Train longer if the result is not good.
    if True:
        for i in range(len(model.layers)):
            model.layers[i].trainable = True
        model.compile(optimizer=Adam(lr=1e-4), loss={'yolo_loss': lambda y_true, y_pred: y_pred}) # recompile to apply the change
        print('Unfreeze all of the layers.')

        # batch_size = 32, 16 # note that more GPU memory is required after unfreezing the body
        batch_size = 16 # note that more GPU memory is required after unfreezing the body
        print('Train on {} samples, val on {} samples, with batch size {}.'.format(num_train, num_val, batch_size))
        model.fit_generator(data_generator_wrapper(lines[:num_train], batch_size, input_shape, anchors, num_classes),
            steps_per_epoch=max(1, num_train//batch_size),
            validation_data=data_generator_wrapper(lines[num_train:], batch_size, input_shape, anchors, num_classes),
            validation_steps=max(1, num_val//batch_size),
            epochs=100, 
            initial_epoch=50,
            callbacks=[logging, checkpoint, reduce_lr, early_stopping])
        model.save_weights(log_dir + 'trained_weights_final.h5')

    # Further training if needed.


def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape(-1, 2)


def create_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
  #          weights_path='model_data/yolo_weights.h5'):
              weights_path='/home/ubuntu/cell/keras-yolo3/yolov3.h5'): # Modified
    '''create the training model'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16, 2:8}[l], w//{0:32, 1:16, 2:8}[l], \
        num_anchors//3, num_classes+5)) for l in range(3)]

    model_body = yolo_body(image_input, num_anchors//3, num_classes)
    print('Create YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze darknet53 body or freeze all but 3 output layers.
            num = (185, len(model_body.layers)-3)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.5})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def create_tiny_model(input_shape, anchors, num_classes, load_pretrained=True, freeze_body=2,
           # weights_path='model_data/tiny_yolo_weights.h5'):
              weights_path='/home/ubuntu/cell/keras-yolo3/yolov3_tiny.h5'): # modified
    '''create the training model, for Tiny YOLOv3'''
    K.clear_session() # get a new session
    image_input = Input(shape=(None, None, 3))
    h, w = input_shape
    num_anchors = len(anchors)

    y_true = [Input(shape=(h//{0:32, 1:16}[l], w//{0:32, 1:16}[l], \
        num_anchors//2, num_classes+5)) for l in range(2)]

    model_body = tiny_yolo_body(image_input, num_anchors//2, num_classes)
    print('Create Tiny YOLOv3 model with {} anchors and {} classes.'.format(num_anchors, num_classes))

    if load_pretrained:
        model_body.load_weights(weights_path, by_name=True, skip_mismatch=True)
        print('Load weights {}.'.format(weights_path))
        if freeze_body in [1, 2]:
            # Freeze the darknet body or freeze all but 2 output layers.
            num = (20, len(model_body.layers)-2)[freeze_body-1]
            for i in range(num): model_body.layers[i].trainable = False
            print('Freeze the first {} layers of total {} layers.'.format(num, len(model_body.layers)))

    model_loss = Lambda(yolo_loss, output_shape=(1,), name='yolo_loss',
        arguments={'anchors': anchors, 'num_classes': num_classes, 'ignore_thresh': 0.7})(
        [*model_body.output, *y_true])
    model = Model([model_body.input, *y_true], model_loss)

    return model

def data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes):
    '''data generator for fit_generator'''
    n = len(annotation_lines)
    i = 0
    while True:
        image_data = []
        box_data = []
        for b in range(batch_size):
            if i==0:
                np.random.shuffle(annotation_lines)
            image, box = get_random_data(annotation_lines[i], input_shape, random=True)
            image_data.append(image)
            box_data.append(box)
            i = (i+1) % n
        image_data = np.array(image_data)
        box_data = np.array(box_data)
        y_true = preprocess_true_boxes(box_data, input_shape, anchors, num_classes)
        yield [image_data, *y_true], np.zeros(batch_size)

def data_generator_wrapper(annotation_lines, batch_size, input_shape, anchors, num_classes):
    n = len(annotation_lines)
    if n==0 or batch_size<=0: return None
    return data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes)

_main()
# Out:
# Using TensorFlow backend.
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9536\661914616.py in <module>
#     200     return data_generator(annotation_lines, batch_size, input_shape, anchors, num_classes)
#     201
# --> 202 _main()
#
# ~\AppData\Local\Temp\ipykernel_9536\661914616.py in _main()
#      24     classes_path = '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt'
#      25     anchors_path = '/home/ubuntu/cell/keras-yolo3/model_data/yolo_anchors.txt'
# ---> 26     class_names = get_classes(classes_path)
#      27     num_classes = len(class_names)
#      28     anchors = get_anchors(anchors_path)
#
# ~\AppData\Local\Temp\ipykernel_9536\661914616.py in get_classes(classes_path)
#     101 def get_classes(classes_path):
#     102     '''loads the classes'''
# --> 103     with open(classes_path) as f:
#     104         class_names = f.readlines()
#     105     class_names = [c.strip() for c in class_names]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt'

# %%
#%cd /content/keras-yolo3/logs/000
#! rm *
# Out:
# /content/keras-yolo3/logs/000

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
# !ls -al logs/000
# Out:
# ls: cannot access 'logs/000': No such file or directory

# %%
# !ls -al /content/keras-yolo3/logs/000
# Out:
# total 6048752
# drwxr-xr-x 2 root root      4096 Jul 26 11:52 .
# drwxr-xr-x 3 root root      4096 Jul 26 05:28 ..
# -rw-r--r-- 1 root root 246996112 Jul 26 05:34 ep003-loss2038.775-val_loss1393.639.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 05:39 ep006-loss976.141-val_loss793.180.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 05:44 ep009-loss665.646-val_loss568.250.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 05:50 ep012-loss553.357-val_loss431.772.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 05:55 ep015-loss463.574-val_loss408.581.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:00 ep018-loss405.091-val_loss350.447.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:06 ep021-loss378.859-val_loss337.497.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:11 ep024-loss351.501-val_loss324.915.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:17 ep027-loss327.206-val_loss313.538.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:22 ep030-loss309.051-val_loss313.321.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:27 ep033-loss306.858-val_loss299.606.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:33 ep036-loss301.236-val_loss292.391.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:38 ep039-loss287.514-val_loss281.758.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:49 ep045-loss292.865-val_loss279.134.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 07:06 ep051-loss237.202-val_loss222.283.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 07:29 ep054-loss203.464-val_loss204.248.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 07:51 ep057-loss194.911-val_loss190.557.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 08:13 ep060-loss191.252-val_loss186.214.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 08:36 ep063-loss185.111-val_loss186.052.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 08:58 ep066-loss180.928-val_loss181.687.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 09:42 ep072-loss182.632-val_loss181.281.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 10:27 ep078-loss178.097-val_loss179.537.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 10:50 ep081-loss178.720-val_loss166.637.h5
# -rw-r--r-- 1 root root   6080625 Jul 26 06:58 events.out.tfevents.1627277298.bcd9da014c22
# -rw-r--r-- 1 root root  12898903 Jul 26 11:52 events.out.tfevents.1627282701.bcd9da014c22
# -rw-r--r-- 1 root root 246996112 Jul 26 11:52 trained_weights_final.h5
# -rw-r--r-- 1 root root 246996112 Jul 26 06:58 trained_weights_stage_1.h5

# %%
# %cd C:\Users\MSI\Cell_linux\keras-yolo3
# Out:
# C:\Users\MSI\Cell_linux\keras-yolo3

# %%
# -*- coding: utf-8 -*-
"""
Class definition of YOLO_v3 style detection model on image and video
"""

import colorsys
import os
from timeit import default_timer as timer

import numpy as np
from keras import backend as K
from keras.models import load_model
from keras.layers import Input
from PIL import Image, ImageFont, ImageDraw

from yolo3.model import yolo_eval, yolo_body, tiny_yolo_body
from yolo3.utils import letterbox_image
import os
from keras.utils import multi_gpu_model

class YOLO(object):
    _defaults = {
        "model_path": 'model_data/yolo.h5',
        "anchors_path": 'model_data/yolo_anchors.txt',
        "classes_path": 'model_data/classes.txt', #2021 0902 수정
        "score" : 0.2, #"score" : 0.3,
        "iou" : 0.35, #"iou" : 0.45,
        "model_image_size" : (640, 480),
        "gpu_num" : 1,
    }

    @classmethod
    def get_defaults(cls, n):
        if n in cls._defaults:
            return cls._defaults[n]
        else:
            return "Unrecognized attribute name '" + n + "'"

    def __init__(self, **kwargs):
        self.__dict__.update(self._defaults) # set up default values
        self.__dict__.update(kwargs) # and update with user overrides
        self.class_names = self._get_class()
        self.anchors = self._get_anchors()
        self.sess = K.get_session()
        self.boxes, self.scores, self.classes = self.generate()

    def _get_class(self):
        classes_path = os.path.expanduser(self.classes_path)
        with open(classes_path) as f:
            class_names = f.readlines()
        class_names = [c.strip() for c in class_names]
        return class_names

    def _get_anchors(self):
        anchors_path = os.path.expanduser(self.anchors_path)
        with open(anchors_path) as f:
            anchors = f.readline()
        anchors = [float(x) for x in anchors.split(',')]
        return np.array(anchors).reshape(-1, 2)

    def generate(self):
        model_path = os.path.expanduser(self.model_path)
        assert model_path.endswith('.h5'), 'Keras model or weights must be a .h5 file.'

        # Load model, or construct model and load weights.
        num_anchors = len(self.anchors)
        num_classes = len(self.class_names)
        is_tiny_version = num_anchors==6 # default setting
        try:
            self.yolo_model = load_model(model_path, compile=False)
        except:
            self.yolo_model = tiny_yolo_body(Input(shape=(None,None,3)), num_anchors//2, num_classes) \
                if is_tiny_version else yolo_body(Input(shape=(None,None,3)), num_anchors//3, num_classes)
            self.yolo_model.load_weights(self.model_path) # make sure model, anchors and classes match
        else:
            assert self.yolo_model.layers[-1].output_shape[-1] == \
                num_anchors/len(self.yolo_model.output) * (num_classes + 5), \
                'Mismatch between model and given anchor and class sizes'

        print('{} model, anchors, and classes loaded.'.format(model_path))

        # Generate colors for drawing bounding boxes.
        hsv_tuples = [(x / len(self.class_names), 1., 1.)
                      for x in range(len(self.class_names))]
        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
        self.colors = list(
            map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)),
                self.colors))
        np.random.seed(10101)  # Fixed seed for consistent colors across runs.
        np.random.shuffle(self.colors)  # Shuffle colors to decorrelate adjacent classes.
        np.random.seed(None)  # Reset seed to default.

        # Generate output tensor targets for filtered bounding boxes.
        self.input_image_shape = K.placeholder(shape=(2, ))
        if self.gpu_num>=2:
            self.yolo_model = multi_gpu_model(self.yolo_model, gpus=self.gpu_num)
        boxes, scores, classes = yolo_eval(self.yolo_model.output, self.anchors,
                len(self.class_names), self.input_image_shape,
                score_threshold=self.score, iou_threshold=self.iou)
        return boxes, scores, classes

    def detect_image(self, image):
        start = timer()

        if self.model_image_size != (None, None):
            assert self.model_image_size[0]%32 == 0, 'Multiples of 32 required'
            assert self.model_image_size[1]%32 == 0, 'Multiples of 32 required'
            boxed_image = letterbox_image(image, tuple(reversed(self.model_image_size)))
        else:
            new_image_size = (image.width - (image.width % 32),
                              image.height - (image.height % 32))
            boxed_image = letterbox_image(image, new_image_size)
        image_data = np.array(boxed_image, dtype='float32')

        print(image_data.shape)
        image_data /= 255.
        image_data = np.expand_dims(image_data, 0)  # Add batch dimension.

        out_boxes, out_scores, out_classes = self.sess.run(
            [self.boxes, self.scores, self.classes],
            feed_dict={
                self.yolo_model.input: image_data,
                self.input_image_shape: [image.size[1], image.size[0]],
                K.learning_phase(): 0
            })

        print('Found {} boxes for {}'.format(len(out_boxes), 'img'))

        font = ImageFont.truetype(font='font/FiraMono-Medium.otf',
                    size=np.floor(3e-2 * image.size[1] + 0.5).astype('int32'))
        thickness = (image.size[0] + image.size[1]) // 300

        for i, c in reversed(list(enumerate(out_classes))):
            predicted_class = self.class_names[c]
            box = out_boxes[i]
            score = out_scores[i]

            label = '{} {:.2f}'.format(predicted_class, score)
            draw = ImageDraw.Draw(image)
            label_size = draw.textsize(label, font)

            top, left, bottom, right = box
            top = max(0, np.floor(top + 0.5).astype('int32'))
            left = max(0, np.floor(left + 0.5).astype('int32'))
            bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32'))
            right = min(image.size[0], np.floor(right + 0.5).astype('int32'))
            print(label, (left, top), (right, bottom))

            if top - label_size[1] >= 0:
                text_origin = np.array([left, top - label_size[1]])
            else:
                text_origin = np.array([left, top + 1])

            # My kingdom for a good redistributable image drawing library.
            for i in range(thickness):
                draw.rectangle(
                    [left + i, top + i, right - i, bottom - i],
                    outline=self.colors[c])
            draw.rectangle(
                [tuple(text_origin), tuple(text_origin + label_size)],
                fill=self.colors[c])
            draw.text(text_origin, label, fill=(0, 0, 0), font=font)
            del draw

        end = timer()
        print(end - start)
        return image

    def close_session(self):
        self.sess.close()

def detect_video(yolo, video_path, output_path=""):
    import cv2
    vid = cv2.VideoCapture(video_path)
    if not vid.isOpened():
        raise IOError("Couldn't open webcam or video")
    video_FourCC    = int(vid.get(cv2.CAP_PROP_FOURCC))
    video_fps       = vid.get(cv2.CAP_PROP_FPS)
    video_size      = (int(vid.get(cv2.CAP_PROP_FRAME_WIDTH)),
                        int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    isOutput = True if output_path != "" else False
    if isOutput:
        print("!!! TYPE:", type(output_path), type(video_FourCC), type(video_fps), type(video_size))
        out = cv2.VideoWriter(output_path, video_FourCC, video_fps, video_size)
    accum_time = 0
    curr_fps = 0
    fps = "FPS: ??"
    prev_time = timer()
    while True:
        return_value, frame = vid.read()
        image = Image.fromarray(frame)
        image = yolo.detect_image(image)
        result = np.asarray(image)
        curr_time = timer()
        exec_time = curr_time - prev_time
        prev_time = curr_time
        accum_time = accum_time + exec_time
        curr_fps = curr_fps + 1
        if accum_time > 1:
            accum_time = accum_time - 1
            fps = "FPS: " + str(curr_fps)
            curr_fps = 0
        cv2.putText(result, text=fps, org=(3, 15), fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                    fontScale=0.50, color=(255, 0, 0), thickness=2)
        cv2.namedWindow("result", cv2.WINDOW_NORMAL)
        cv2.imshow("result", result)
        if isOutput:
            out.write(result)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    yolo.close_session()
# Out:
# Using TensorFlow backend.
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 물체 탐지 실행

# %%
from IPython.display import display 
from PIL import Image
from yolo import YOLO

def do_object_detection(file, model_path, class_path):
  
  yolo = YOLO(model_path=model_path, classes_path=class_path)

  # 이미지 로딩
  image = Image.open(file)

  # 실행
  result_image = yolo.detect_image(image)

  # 실행 결과 표시
  display(result_image)

# %%
import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/JPEGImages/01_P2--0030.jpg', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

# %%
# new machine

import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0067.jpg', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

#220117_Interval_0279.jpg

# %%
# new machine ImageFilter.EDGE_ENHANCE 적용

import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.png', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

# %%
import os

do_object_detection('/home/ubuntu/cell/keras-yolo3/crop_to_4/JPEGImages/01_P2--0030.jpg', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt')

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')

# %%
import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/data_flip/JPEGImages/P2--0030.jpg', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')
/
# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')

# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
#      --------------------------------------- 35.4/35.4 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in c:\users\msi\appdata\local\programs\python\python37\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\msi\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import re
import numpy as np
from PIL import Image
from PIL import ImageFilter


#img = cv2.imread('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0279.jpg',0);
img = Image.open('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0279.jpg')

# contrast limit가 2이고 title의 size는 8X8
'''
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img2 = clahe.apply(img)

pil_img = Image.fromarray(img2)'''


img_edge = img.filter(ImageFilter.EDGE_ENHANCE)
img_edge.save('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.png')

#cv2.imwrite('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.png',img2)

# %%
# new machine clahe 적용

import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.png', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

# %%
import cv2
import re
import numpy as np
from PIL import Image
from PIL import ImageFilter


img = cv2.imread('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0279.jpg',0);

#img = Image.open('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0279.jpg')

# contrast limit가 2이고 title의 size는 8X8

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img2 = clahe.apply(img)

#pil_img = Image.fromarray(img2)
img2_ = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

#img_edge = img.filter(ImageFilter.EDGE_ENHANCE)
#img_edge.save('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.png')

cv2.imwrite('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.jpg',img2_)
# Out:
# True

# %%
# new machine clahe 적용

import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/clahe_220117_Interval_0279.jpg', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

# %%
# new machine clahe 적용

import os

do_object_detection('C:/Users/MSI/Cell_linux/keras-yolo3/newmachine/220117_Interval_0279.jpg', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    'C:/Users/MSI/Cell_linux/keras-yolo3/crop_to_4/classes.txt')

# %%
import os

do_object_detection('/home/ubuntu/cell/keras-yolo3/data_flip/JPEGImages/P2--0030.jpg', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt')

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')

# %%
import os

for root, dirs, files in os.walk("/home/ubuntu/cell/keras-yolo3/crop_to_4/test/"):
    for filename in files:
      print(filename)
      do_object_detection('/home/ubuntu/cell/keras-yolo3/crop_to_4/test/' + filename, \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt')

# %%
import os

do_object_detection('/home/ubuntu/cell/keras-yolo3/data_flip/JPEGImages/P2--0030.jpg', \
                    '/home/ubuntu/cell/keras-yolo3/data_flip/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/data_flip/classes.txt')

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')

# %%
import os

do_object_detection('/home/ubuntu/cell/keras-yolo3/data_flip/JPEGImages/P2--0030.jpg', \
                    '/home/ubuntu/cell/keras-yolo3/data/logs/trained_weights_final_2020.h5', \
                    '/home/ubuntu/cell/keras-yolo3/data_flip/classes.txt')

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')

# %%
# %cd /home/ubuntu/cell/keras-yolo3
# Out:
# /home/ubuntu/cell/keras-yolo3

# %%
import os

for root, dirs, files in os.walk("/home/ubuntu/cell/keras-yolo3/newmachine/"):
    for filename in files:
      print(filename)
      do_object_detection('/home/ubuntu/cell/keras-yolo3/newmachine/' + filename, \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/logs/000/trained_weights_final.h5', \
                    '/home/ubuntu/cell/keras-yolo3/crop_to_4/classes.txt')

# do_object_detection('/content/0945.jpg', 'logs/000/ep063-loss69.857-val_loss72.440.h5', 'dental_image_in_voc_format/classes.txt')
